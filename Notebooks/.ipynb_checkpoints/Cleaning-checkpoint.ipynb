# %% [markdown]
# Importing relevant packages

# %%
#pip install -U epiweeks

# %%
import pandas as pd 
import numpy as np 
import pickle 
import datetime as dt
#import epiweeks as ew
from epiweeks import Week, Year
import os
import glob

# %% [markdown]
# Opening pickles!

# %%
with open('df_temp_rain.pickle','rb') as read_file:
    df_temp_rain = pickle.load(read_file)
with open('df_dengue.pickle','rb') as read_file:
    df_dengue = pickle.load(read_file)

# %% [markdown]
# Opening and merging search term CSVs

# %%
os.chdir("/Users/adelweiss/Documents/Project/Project 2/Data")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

counter = 0
df_st = pd.DataFrame
#combine all files in the list
for name in all_filenames:
    csvfile = pd.read_csv(name, skiprows=2)
    if counter == 0:
        df_st = csvfile 
        counter +=1
    else: df_st = df_st.merge(csvfile, how = 'left', on ='Week' )

# %%
df_st
# Out:
#            Week  fever: (Singapore)  headache: (Singapore)  \
# 0    2014-01-05                  71                     75
# 1    2014-01-12                  84                     52
# 2    2014-01-19                  72                     56
# 3    2014-01-26                  66                     69
# 4    2014-02-02                  64                     65
# ..          ...                 ...                    ...
# 256  2018-12-02                  82                     70
# 257  2018-12-09                  67                     56
# 258  2018-12-16                  77                     76
# 259  2018-12-23                  84                     75
# 260  2018-12-30                  89                     83
#
#      ache + pain: (Singapore)  dengue fever: (Singapore)  \
# 0                          83                         46
# 1                          77                         29
# 2                          75                         40
# 3                          73                         18
# 4                          80                         35
# ..                        ...                        ...
# 256                        77                         24
# 257                        87                         15
# 258                        84                         27
# 259                        88                         24
# 260                        89                         30
#
#      eye pain: (Singapore)  dengue: (Singapore)  rashes: (Singapore)
# 0                       32                   68                   82
# 1                       57                   61                   73
# 2                       48                   47                   78
# 3                       43                   34                   84
# 4                       43                   42                   58
# ..                     ...                  ...                  ...
# 256                     59                   29                   54
# 257                     81                   26                   58
# 258                     61                   28                   60
# 259                     71                   20                   72
# 260                     41                   27                   59
#
# [261 rows x 8 columns]

# %% [markdown]
# Dengue DataFrame

# %%
df_dengue.info()
### There seems to be cases missing form Number column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 810 entries, 0 to 14
# Data columns (total 4 columns):
# Year            810 non-null int64
# Eweek (Week)    810 non-null int64
# Type dengue     810 non-null object
# Number          796 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 31.6+ KB

# %%
###Keep only normal dengue cases, unfortunately this does not solve the missing data problem
df_dengue = df_dengue[df_dengue['Type dengue'] == 'Dengue']

# %%
df_dengue[df_dengue['Number'].isnull()]

### NaN in Number columns occur on week 53... let's drop these. 
### also there appears to be some duplicates in the dataframe, which explains the weird total entries
# Out:
#     Year  Eweek (Week) Type dengue  Number
# 14  2018            53      Dengue     NaN
# 0   2018            53      Dengue     NaN
# 1   2017            53      Dengue     NaN
# 2   2017            53      Dengue     NaN
# 10  2016            53      Dengue     NaN
# 11  2016            53      Dengue     NaN
# 12  2015            53      Dengue     NaN

# %%
df_dengue.drop_duplicates(keep = 'last', inplace = True)

# %%
### we need to zero-pad the single digits of eweek and concate the year 
### so that we can merge this with the other datasets. 

df_dengue['Eweek (Week)'] = df_dengue['Eweek (Week)'].astype(str)
df_dengue['Eweek (Week)'] = df_dengue['Eweek (Week)'].apply(lambda x: x.zfill(2))

# %%
### now we need to merge the year and the eweeek
df_dengue['Year'] = df_dengue['Year'].astype(str)
df_dengue['eweek'] = df_dengue[['Year', 'Eweek (Week)']].apply(lambda x: ''.join(x), axis=1)

# %%
df_dengue = df_dengue.drop(columns = ['Year', 'Eweek (Week)', 'Type dengue'])

# %%
df_dengue.rename(columns={'Number':'Dengue Cases'}, inplace=True)

# %%
df_dengue
# Out:
#     Dengue Cases   eweek
# 1           83.0  201801
# 3           68.0  201802
# 5           54.0  201803
# 7           45.0  201804
# 9           48.0  201805
# ..           ...     ...
# 5          212.0  201449
# 7          177.0  201450
# 9          198.0  201451
# 11         188.0  201452
# 13         158.0  201453
#
# [265 rows x 2 columns]

# %% [markdown]
# Temperature & Rainfall

# %%
df_temp_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1827 entries, 0 to 30
# Data columns (total 11 columns):
# Date                             1827 non-null object
# Daily Rainfall Total (mm)        1827 non-null float64
# Highest 30-min Rainfall (mm)     1827 non-null object
# Highest 60-min Rainfall (mm)     1827 non-null object
# Highest 120-min Rainfall (mm)    1827 non-null object
# Mean Temperature (°C)            1827 non-null float64
# Maximum Temperature (°C)         1827 non-null float64
# Minimum Temperature (°C)         1827 non-null float64
# Mean Wind Speed (km/h)           1827 non-null object
# Max Wind Speed (km/h)            1827 non-null object
# Year                             1827 non-null int64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 171.3+ KB

# %%
df_temp_rain.describe()
# Out:
#        Daily Rainfall Total (mm)  Mean Temperature (°C)  \
# count                1827.000000            1827.000000
# mean                    4.631253              28.051013
# std                    10.299263               1.116300
# min                     0.000000              23.000000
# 25%                     0.000000              27.300000
# 50%                     0.000000              28.100000
# 75%                     3.600000              28.900000
# max                    75.400000              30.700000
#
#        Maximum Temperature (°C)  Minimum Temperature (°C)         Year
# count               1827.000000               1827.000000  1827.000000
# mean                  31.654953                 25.497865  2016.002189
# std                    1.471560                  1.340702     1.414212
# min                   23.700000                 21.100000  2014.000000
# 25%                   30.900000                 24.600000  2015.000000
# 50%                   31.900000                 25.500000  2016.000000
# 75%                   32.600000                 26.500000  2017.000000
# max                   35.000000                 28.400000  2018.000000

# %%
### Need to turn the days into epi week
### Each epidemiological week begins on a Sunday and ends on Saturday

# %%
###Split date into day and month so that I can apply the epiweek conversion 
df_temp_rain['Date2'] = df_temp_rain['Date'].str.split() 
df_temp_rain['Day'] = df_temp_rain['Date2'].apply(lambda x:x[0])
df_temp_rain['Month'] = df_temp_rain['Date2'].apply(lambda x:x[1])

# %%
###apply dictionary to months so that we can use epi week to convert 
month_dictionary = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4,'May':5,
                    'Jun':6,'Jul':7,'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12} 

df_temp_rain['Month_Number']= df_temp_rain['Month'].apply(lambda x: month_dictionary[x])

# %%
### define function to apply convert epi weeks... 
def epi_week_conversion(row, df):
    data_date = dt.date(int(df['Year'].iloc[row]), int(df['Month_Number'].iloc[row]), int(df['Day'].iloc[row])) 
    return str(Week.fromdate(data_date))
#my_date = date(int(df.Year.iloc[row]), int(df.Month_Number.iloc[row]),int(df.Day.iloc)[row])int(df.Day.iloc)[row])))

# %%
### function needs to reference index..
## original index is out-of-order..so creating an index column by resetting index twice 
df_temp_rain.reset_index(inplace=True)
df_temp_rain.reset_index(inplace=True)

# %%
df_temp_rain['eweek'] = 1 #initialise column 
df_temp_rain['eweek'] = df_temp_rain['level_0'].apply(lambda x:epi_week_conversion(x,df_temp_rain))

# %%
df_temp_rain.drop(columns = ['level_0','index','Date','Year', 'Month', 'Month_Number', 'Date2', 'Day'], inplace=True)

# %%
### need to groupby since this data was by day, we will take the mean of each variable 
df_temp_rain_byweek = df_temp_rain.groupby('eweek').mean()

# %% [markdown]
# Search Terms DataFrame

# %%
###Split date so that I can apply the epiweek conversion 
df_st['Week1'] = df_st['Week'].str.split('-') 
df_st['Day'] = df_st['Week1'].apply(lambda x:x[2])
df_st['Month_Number'] = df_st['Week1'].apply(lambda x:x[1]) 
df_st['Year'] = df_st['Week1'].apply(lambda x:x[0])

# %%
df_st.reset_index(inplace=True)

# %%
df_st['eweek'] = 1 #initialise column 
df_st['eweek'] = df_st['index'].apply(lambda x: epi_week_conversion(x,df_st))

# %%
df_st.drop(columns=['Week','index', 'Week1', 'Day', 'Month_Number', 'Year'], inplace = True)

# %%
df_st
# Out:
#      fever: (Singapore)  headache: (Singapore)  ache + pain: (Singapore)  \
# 0                    71                     75                        83
# 1                    84                     52                        77
# 2                    72                     56                        75
# 3                    66                     69                        73
# 4                    64                     65                        80
# ..                  ...                    ...                       ...
# 256                  82                     70                        77
# 257                  67                     56                        87
# 258                  77                     76                        84
# 259                  84                     75                        88
# 260                  89                     83                        89
#
#      dengue fever: (Singapore)  eye pain: (Singapore)  dengue: (Singapore)  \
# 0                           46                     32                   68
# 1                           29                     57                   61
# 2                           40                     48                   47
# 3                           18                     43                   34
# 4                           35                     43                   42
# ..                         ...                    ...                  ...
# 256                         24                     59                   29
# 257                         15                     81                   26
# 258                         27                     61                   28
# 259                         24                     71                   20
# 260                         30                     41                   27
#
#      rashes: (Singapore)   eweek
# 0                     82  201402
# 1                     73  201403
# 2                     78  201404
# 3                     84  201405
# 4                     58  201406
# ..                   ...     ...
# 256                   54  201849
# 257                   58  201850
# 258                   60  201851
# 259                   72  201852
# 260                   59  201901
#
# [261 rows x 8 columns]

# %% [markdown]
# Merging all data files!

# %%
df = df_dengue.merge(df_temp_rain_byweek, how = 'left', on ='eweek' ).merge(df_st, how = 'left', on ='eweek')

# %%
df
# Out:
#      Dengue Cases   eweek  Daily Rainfall Total (mm)  Mean Temperature (°C)  \
# 0            83.0  201801                  14.228571              25.828571
# 1            68.0  201802                  19.971429              24.985714
# 2            54.0  201803                   4.800000              26.057143
# 3            45.0  201804                   3.114286              26.900000
# 4            48.0  201805                   9.800000              26.942857
# ..            ...     ...                        ...                    ...
# 260         212.0  201449                  10.371429              27.371429
# 261         177.0  201450                   5.028571              27.914286
# 262         198.0  201451                   5.514286              27.128571
# 263         188.0  201452                  13.714286              26.571429
# 264         158.0  201453                   0.542857              26.214286
#
#      Maximum Temperature (°C)  Minimum Temperature (°C)  fever: (Singapore)  \
# 0                   28.242857                 24.214286                65.0
# 1                   27.471429                 23.200000                82.0
# 2                   30.057143                 23.671429                80.0
# 3                   31.400000                 24.885714                76.0
# 4                   31.357143                 24.200000                79.0
# ..                        ...                       ...                 ...
# 260                 30.942857                 24.214286                60.0
# 261                 31.928571                 25.257143                66.0
# 262                 30.571429                 25.042857                59.0
# 263                 30.242857                 24.657143                58.0
# 264                 29.085714                 24.500000                66.0
#
#      headache: (Singapore)  ache + pain: (Singapore)  \
# 0                     80.0                      90.0
# 1                     90.0                      93.0
# 2                     78.0                      88.0
# 3                     85.0                     100.0
# 4                     98.0                      93.0
# ..                     ...                       ...
# 260                   82.0                      76.0
# 261                   62.0                      75.0
# 262                   57.0                      75.0
# 263                   50.0                      81.0
# 264                   67.0                      74.0
#
#      dengue fever: (Singapore)  eye pain: (Singapore)  dengue: (Singapore)  \
# 0                          8.0                   57.0                 17.0
# 1                         30.0                   44.0                 23.0
# 2                         23.0                   24.0                 21.0
# 3                         19.0                   63.0                 23.0
# 4                         10.0                   20.0                 17.0
# ..                         ...                    ...                  ...
# 260                       26.0                   49.0                 27.0
# 261                       30.0                   38.0                 28.0
# 262                       25.0                   91.0                 24.0
# 263                       22.0                   48.0                 23.0
# 264                       26.0                   39.0                 21.0
#
#      rashes: (Singapore)
# 0                   70.0
# 1                   61.0
# 2                   57.0
# 3                   79.0
# 4                   70.0
# ..                   ...
# 260                 71.0
# 261                 44.0
# 262                 69.0
# 263                 52.0
# 264                 75.0
#
# [265 rows x 13 columns]

# %%
with open('df.pickle', 'wb') as to_write:  
    pickle.dump(df, to_write)
