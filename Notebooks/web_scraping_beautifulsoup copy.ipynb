# %% [markdown]
# ## Web Scraping 101: BeautifulSoup

# %% [markdown]
# [BeautifulSoup documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# Scraping data from the internet.
#
# Web scraping is simple due to the consistent format of information among web pages.

# %% [markdown]
# ## HTML Refresher

# %% [markdown]
# ### Overview
# * HTML is the basic language used to create a web page.
# * It tells the web browser what text/media to display, where to display it, and how to display it (style)
# * HTML is very structured/hirarchical.
# * Every page is made up of discrete "elements."

# %% [markdown]
# ### Tags
#
# * Elements are labeled with "tags."
#
# * For example:
#
#     ```html
#     <p>You are beginning to learn HTML.</p>
#     ```

# %% [markdown]
# ### Attributes
#
# * A start tag also often contains "attributes" with info about the element.
#
# * Attributes usually have a name and value.
#
# * Example:
#
# ```html
# <p class="my_red_sentences">You are beginning to learn HTML.</p>
# ```

# %% [markdown]
# ### Structure
#
# A full HTML document has a structure more like this:
#
# ```html
# <html>
#   <head> </head>
#   <body>
#      <p class="red">You are beginning to learn HTML.</p>
#      <h1> This is a header </h1>
#      <a href="www.google.com"> Some link </a>
#   </body>
# </html>
# ```

# %% [markdown]
# ### Explore in Browser
#
# * Let's explore some live HTML!
# * Go to http://boxofficemojo.com/movies/?id=biglebowski.htm in your browser, preferably Chrome.
# * Click Inspect Element, also click on View Page Source.

# %% [markdown]
# ## HTML to BeautifulSoup

# %% [markdown]
# ### Request data for The Big Lebowski
#
# Scrape some information about [The Big Lebowski](http://boxofficemojo.com/movies/?id=biglebowski.htm).

# %%
from __future__ import print_function, division

# %%
# if needed: pip install requests or conda install requests
import requests

requests.__path__
# Out:
# ['//anaconda3/lib/python3.7/site-packages/requests']

# %%
url = 'https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases'

response = requests.get(url)

# %% [markdown]
# ### Check the Status
#
# For information on HTTP status codes, see:
#
# https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %%
response.status_code # status code = 200 => OK
# Out:
# 200

# %% [markdown]
# ### Look at the Text

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="en_GB">
#
#
#   <head>
#     <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2019-10-14T11:24:30/html5.min.js"></script><![endif]-->
# <link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2019-10-14T11:24:30/select2/select2.css" />
# <link rel="stylesheet" type="text/css" href="/fanstatic/datagovsg-css/:version:2019-10-14T11:42:38.32/datagovsg.min.css" />
# <link rel="stylesheet" type="text/css" href="/fanstatic/datagovsg-css/:version:2019-10-14T11:42:38.32/package/read.min.css" />
# <link rel="stylesheet" type="text/css" href="/fanstatic/datagovsg-css/:version:2019-10-14T11:42:38.32/package/snippets/resource_item_fields.min.css" />
#
#
#     <title>
#       Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases-Data.gov.sg
#
#     </title>
#
#
#     <meta charset="utf-8">
#     <meta name="generator" content="ckan ">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" user-scalable="no">
#     <meta name="description" content="This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018.">
#     <meta name="theme-color" content="#113355">
#     <meta name="application-name" content="Data.gov.sg">
#
#     <meta name="twitter:card" content="summary_large_image">
#     <meta name="twitter:site" content="@datagovsg">
#     <meta name="twitter:title" content="Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases-Data.gov.sg
#       ">
#     <meta name="twitter:description" content="This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018.">
#     <meta name="twitter:url" content="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases">
#     <meta name="twitter:image:src" content="https://data.gov.sg/images/thumbnail.png">
#
#     <meta property="og:title" content="Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases-Data.gov.sg
#       " />
#     <meta property="og:description" content="This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018." />
#     <meta property="og:type" content="article" >
#     <meta property="og:url" content="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases" >
#     <meta property="og:image" content="https://data.gov.sg/images/thumbnail.png" >
#     <meta property="og:site_name" content="Data.gov.sg" >
#
#     <meta name="apple-mobile-web-app-title" content="Data.gov.sg">
#
#     <meta name="msapplication-TileColor" content="#113355">
#     <meta name="msapplication-TileImage" content="images/favicons/mstile-144x144.png">
#
#
#
#     <link rel="manifest" href="/manifest.json">
#
#     <link rel="mask-icon" href="/images/favicons/safari-pinned-tab.svg" color="#223344">
#
#     <link rel="shortcut icon" href="/images/favicon.ico" >
#     <link rel="icon" type="image/png" href="/images/favicons/favicon-16x16.png" sizes="16x16">
#     <link rel="icon" type="image/png" href="/images/favicons/favicon-32x32.png" sizes="32x32">
#     <link rel="icon" type="image/png" href="/images/favicons/favicon-96x96.png" sizes="96x96">
#     <link rel="icon" type="image/png" href="/images/favicons/android-chrome-192x192.png" sizes="192x192">
#     <link rel="icon" type="image/png" href="/images/favicons/favicon-194x194.png" sizes="194x194">
#
#     <link rel="apple-touch-icon" sizes="57x57" href="/images/favicons/apple-touch-icon-57x57.png">
#     <link rel="apple-touch-icon" sizes="60x60" href="/images/favicons/apple-touch-icon-60x60.png">
#     <link rel="apple-touch-icon" sizes="72x72" href="/images/favicons/apple-touch-icon-72x72.png">
#     <link rel="apple-touch-icon" sizes="76x76" href="/images/favicons/apple-touch-icon-76x76.png">
#     <link rel="apple-touch-icon" sizes="114x114" href="/images/favicons/apple-touch-icon-114x114.png">
#     <link rel="apple-touch-icon" sizes="120x120" href="/images/favicons/apple-touch-icon-120x120.png">
#     <link rel="apple-touch-icon" sizes="144x144" href="/images/favicons/apple-touch-icon-144x144.png">
#     <link rel="apple-touch-icon" sizes="152x152" href="/images/favicons/apple-touch-icon-152x152.png">
#     <link rel="apple-touch-icon" sizes="180x180" href="/images/favicons/apple-touch-icon-180x180.png">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <script>
#       // Check if script is being ran from Iframe within data.gov.sg.
#       // This prevents dobule counting in Google Analytics tracking when page views are
#       // triggered twice due to embedding of iframe. This allows us to continue tracking
#       // users who are properly embedding the charts.
#       nodeName = window.frameElement ? window.frameElement.nodeName : 'default'
#       if (!(window.location.hostname.indexOf("data.gov.sg") > -1 && nodeName == "IFRAME")) {
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-64941664-1', 'auto');
#         ga('send', 'pageview');
#
#         window.onload = function () {
#           //track resource downloads
#           document.body.addEventListener('click', function(event) {
#             var element = findElWithClass(event);
#             if (element !== null && typeof element.className == "string"){
#               var classes = element.className.split(' ');
#               for (var event_type in ga_events) {
#                 if (classes.indexOf(event_type) > -1 ) {
#                   var eventCategory = ga_events[event_type].eventCategory;
#                   var eventAction = ga_events[event_type].eventAction;
#                   var eventLabel = element.getAttribute("data-ga") + ": " + window.location.href;
#
#                   if (event_type == "ga-dataset-download") {
#                     eventLabel = element.getAttribute("data-ga");
#                   }
#                   ga('send', 'event', eventCategory, eventAction, eventLabel);
#                 }
#               }
#             }
#           });
#         };
#       }
#
#       function findElWithClass(el) {
#         if (el.target) {
#           el = el.target;
#           while (el) {
#             if (typeof el.className == "string"){
#               var classes = el.className.split(' ');
#               for (var event_type in ga_events) {
#                 if (classes.indexOf(event_type) > -1 ) {
#                   return el;
#                 }
#               }
#             }
#             el = el.parentNode;
#           }
#           return null;
#         }
#       }
#     </script>
#
#
#
#   </head>
#
#
#
#   <body>
#
#
#
#     <nav class="site-nav">
#       <div class="container">
#         <a href="/">
#           <img class="site-logo"
#                src="/images/logo.svg"
#                alt="Data.gov.sg"
#                title="Data.gov.sg"/>
#         </a>
#         <a href="/" class="site-title">Data.gov.sg</a>
#         <div class="flex-spacer"></div>
#
#
#         <a class="site-link ga-nav-topic-dropdown" data-toggle="collapse" href=".topic-collapse">Topics<span class="caret"></span></a>
#
#
#
#         <a class="site-link ga-nav-blog" href='https://blog.data.gov.sg'>Blog</a>
#         <a class="site-link ga-nav-developers" href='/developer'>Developers</a>
#         <a class="site-link ga-nav-request" href='https://github.com/datagovsg/datagovsg-datasets/issues/new?title=Dataset%20request:%20%3Cdataset%20title%3E'>Data Request</a>
#
#       </div>
#     </nav>
#
#
#
#     <div class="collapse topic-collapse">
#       <div class="container">
#         <div class="row">
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Economy
#                href="/group/economy">
#               <img class="hover-on" src=/images/group_icons/active/economy.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/economy.svg>
#               <h5 class="topic-title"><small>Economy</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Education
#                href="/group/education">
#               <img class="hover-on" src=/images/group_icons/active/education.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/education.svg>
#               <h5 class="topic-title"><small>Education</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Environment
#                href="/group/environment">
#               <img class="hover-on" src=/images/group_icons/active/environment.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/environment.svg>
#               <h5 class="topic-title"><small>Environment</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Finance
#                href="/group/finance">
#               <img class="hover-on" src=/images/group_icons/active/finance.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/finance.svg>
#               <h5 class="topic-title"><small>Finance</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Health
#                href="/group/health">
#               <img class="hover-on" src=/images/group_icons/active/health.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/health.svg>
#               <h5 class="topic-title"><small>Health</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Infrastructure
#                href="/group/infrastructure">
#               <img class="hover-on" src=/images/group_icons/active/infrastructure.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/infrastructure.svg>
#               <h5 class="topic-title"><small>Infrastructure</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Society
#                href="/group/society">
#               <img class="hover-on" src=/images/group_icons/active/society.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/society.svg>
#               <h5 class="topic-title"><small>Society</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Technology
#                href="/group/technology">
#               <img class="hover-on" src=/images/group_icons/active/technology.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/technology.svg>
#               <h5 class="topic-title"><small>Technology</small></h5>
#             </a>
#           </div>
#
#           <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#             <a class="topic-link ga-nav-topic-selector"
#                data-ga=Transport
#                href="/group/transport">
#               <img class="hover-on" src=/images/group_icons/active/transport.svg>
#               <img class="hover-off" src=/images/group_icons/inactive/transport.svg>
#               <h5 class="topic-title"><small>Transport</small></h5>
#             </a>
#           </div>
#
#         </div>
#       </div>
#     </div>
#
#
#
#     <header class="site-header "
#             style="background-image: url()">
#
#
#
#
#     </header>
#
#
#
#
#
#     <main class="site-main">
#
#
# <div class="header-div">
#   <div class="container">
#     <div class="package-title-section">
#       <h2 class="package-title">Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases</h2>
#       <div class="package-title-buttons">
#
#
#         <a class="btn datagovsg-btn btn-right btn-orange ga-dataset-download"
#           data-ga="f4c6643f-5b70-406e-a631-1f96e0b90712"
#            role="button"
#            href="/dataset/f4c6643f-5b70-406e-a631-1f96e0b90712/download">
#            <img class="button-icon" src='/images/icons/Download.svg'/>
#            Download
#         </a>
#
#
#
#
#       </div>
#     </div>
#   </div>
# </div>
#
# <div class="dataset-resource-views">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="resource-views-header">
#     <div class="resource-selector-header">
#       FILES IN THIS DATASET
#     </div>
# </div>
#
# <div class="resource-views-body">
#
#
#
#
#   <div class="resource-selector-container">
#     <ul class="resource-selector nav hidden-xs">
#
#       <li class="active">
#         <a class="ga-dataset-resource-selector"
#            href="/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4">
#           Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases
#           <div>
#             <img class="format-icon"
#             src=/images/icons/file_type/CSV.svg/>
#           </div>
#         </a>
#       </li>
#
#     </ul>
#   </div>
#
#
#   <div class="resource-detail-container">
#     <div class="resource-detail container-fluid">
#
#
#         <div class="resource-controls-mobile">
#
#
#
#
#
#         </div>
#
#
#
#
#         <div class="resource-controls">
#           <span>Views: </span>
#
#
#
#
#
#             <a class="view-tab ga-dataset-resource-view-selector active table" data-ga=Table href=/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases?view_id=40a6c1fa-842c-420e-ab09-1676a24b2729&amp;resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4>
#               <div></div>
#               <img class="active" src="/images/icons/resource_view_selectors/active/table.svg"/>
#               <img class="inactive" src="/images/icons/resource_view_selectors/inactive/table.svg"/>
#               <img class="inactive hover" src="/images/icons/resource_view_selectors/hover/table.svg"/>
#             </a>
#
#
#           <div class="resource-embed-container">
#
#
#
#
#
#
#
#                 <button class="btn datagovsg-btn btn-right btn-blue desktop-only ga-dataset-data-api"
#                   data-ga=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4
#                   data-toggle="modal"
#                   data-target="#dataAPIModal">
#                   <img class="button-icon" src='/images/icons/Data_API.svg'/>Data API
#                 </button>
#
#
#                 <!-- <div class="modal" id="dataAPIModal"> -->
#
#
# <div class="modal" id="dataAPIModal" tabindex="-1" role="dialog" aria-labelledby="myModalLabel">
#   <div class="modal-dialog" role="document">
#     <div class="modal-content">
#       <div class="modal-header">
#         <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">&times;</span></button>
#         <h4 class="modal-title" id="myModalLabel">View Embedding Instructions</h4>
#       </div>
#       <div class="modal-body">
#         <div class="accordion">
#           <div class="accordion-group">
#             <div class="accordion-heading">
#
#               <a class="accordion-toggle" data-toggle="collapse" data-parent="accordion2" href="#collapse-endpoints">Endpoints &raquo;</a>
#             </div>
#             <div id="collapse-endpoints" class="in accordion-body collapse">
#               <div class="accordion-inner">
#                 <p>The Data API can be accessed via the following actions of the CKAN action API.</p>
#                 <table class="table-condensed table-striped table-bordered">
#                   <thead></thead>
#                   <tbody>
#                     <tr>
#                       <th scope="row">Query</th>
#                       <td><code>https://data.gov.sg/api/action/datastore_search</code></td>
#                     </tr>
#
#                   </tbody>
#                 </table>
#               </div>
#             </div>
#           </div>
#
#           <div class="accordion-group">
#             <div class="accordion-heading">
#               <a class="accordion-toggle" data-toggle="collapse" data-parent="accordion2" href="#collapse-querying">Querying &raquo;</a>
#             </div>
#             <div id="collapse-querying" class="collapse accordion-body in">
#               <div class="accordion-inner">
#                 <strong>Query example (first 5 results)</strong>
#                 <p>
#                 <code><a href="https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&limit=5" target="_blank">https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&limit=5</a></code>
#                 </p>
#
#                 <strong>Query example (results containing &#39;jones&#39;)</strong>
#                 <p>
#                 <code><a href="https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&q=jones"
#                     target="_blank">https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&q=jones</a></code>
#                 </p>
#
#               </div>
#             </div>
#           </div>
#
#           <div class="accordion-group">
#             <div class="accordion-heading">
#              <a class="accordion-toggle" data-toggle="collapse" data-parent="accordion2" href="#collapse-javascript">Example: Javascript &raquo;</a>
#             </div>
#             <div id="collapse-javascript" class="accordion-body collapse">
#               <div class="accordion-inner">
#                 <p>A simple ajax (JSONP) request to the data API using jQuery.</p>
#                 <pre>
# var data = {
#   resource_id: 'c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4', // the resource id
#   limit: 5, // get 5 results
#   q: 'jones' // query for 'jones'
# };
# $.ajax({
#   url: 'https://data.gov.sg/api/action/datastore_search',
#   data: data,
#   dataType: 'jsonp',
#   success: function(data) {
#     alert('Total results found: ' + data.result.total)
#   }
# });
#                 </pre>
#               </div>
#             </div>
#           </div>
#
#           <div class="accordion-group">
#             <div class="accordion-heading">
#               <a class="accordion-toggle" data-toggle="collapse" data-parent="accordion2" href="#collapse-python">Example: Python &raquo;</a>
#             </div>
#             <div id="collapse-python" class="accordion-body collapse">
#               <div class="accordion-inner">
#                 <pre>
# import urllib
# url = 'https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&amp;limit=5&amp;q=title:jones'
# fileobj = urllib.urlopen(url)
# print fileobj.read()
#                 </pre>
#               </div>
#             </div>
#           </div>
#
#
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#                  <!-- </div> -->
#
#
#
#
#
#
#             <button class="btn datagovsg-btn btn-right btn-blue ga-dataset-embed-chart"
#                     data-ga=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4
#                     data-toggle="modal" data-target="#embedModal">
#               <img class="button-icon" src='/images/icons/Embed.svg'/>Embed Chart
#             </button>
#
#
#             <div class="modal" id="embedModal" tabindex="-1" role="dialog" aria-labelledby="myModalLabel">
#               <div class="modal-dialog" role="document">
#                 <div class="modal-content">
#                   <div class="modal-header">
#                     <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">&times;</span></button>
#                     <h4 class="modal-title" id="myModalLabel">View Embedding Instructions</h4>
#                   </div>
#                   <div class="modal-body">
#                     <p>Copy the following html into your webpage to embed this view</p>
#                     <code class="language-html well" data-lage="html">
#                       &lt;iframe
#                       width="600"
#                       height="400"
#                       src="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases/resource/c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4/view/40a6c1fa-842c-420e-ab09-1676a24b2729"
#                       frameBorder="0"&gt;
#                       &lt;/iframe&gt;
#                     </code>
#                   </div>
#                 </div>
#               </div>
#             </div>
#           </div>
#
#
#         </div>
#
#
#
#         <div id="view-40a6c1fa-842c-420e-ab09-1676a24b2729" class="resource-view table-view">
#
#             <iframe frameborder="0"
#                     src="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases/resource/c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4/view/40a6c1fa-842c-420e-ab09-1676a24b2729" ></iframe>
#
#         </div>
#
#
#
#
#
#       <div class="module-content">
#         <div class="resource-description">
#
#             <p>This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018.</p>
#
#         </div>
#
#         <div class="resource-item-fields">
#
#
#
# <span class="title">Columns</span>
# <div class='resource-fields'>
#   <div class="hidden-phone">
#     <table class="table table-condensed" >
#
#       <col class="field-index">
#       <col class="field-name"/>
#       <col class="field-title"/>
#       <col class="field-type"/>
#       <col class="field-units"/>
#       <col class="field-desc"/>
#
#       <thead>
#         <tr>
#           <th class="field-index">No.</th>
#           <th class="field-name">Name</th>
#           <th class="field-title">Title</th>
#           <th class="field-type">Type</th>
#           <th class="field-units">Unit of Measure</th>
#           <th class="field-desc">Description</th>
#         </tr>
#       </thead>
#       <tbody>
#
#         <tr>
#           <td class="field-index" width="10%">1</td>
#           <td>year</td>
#           <td>Year</td>
#           <td class="field-type">
#             Datetime (Year)
#
#               <br>
#               &#34;YYYY&#34;
#
#
#           </td>
#           <td>-</td>
#           <td>
#
#             -
#           </td>
#         </tr>
#
#         <tr>
#           <td class="field-index" width="10%">2</td>
#           <td>eweek</td>
#           <td>Eweek</td>
#           <td class="field-type">
#             Numeric (General)
#
#
#           </td>
#           <td>Week</td>
#           <td>
#
#             -
#           </td>
#         </tr>
#
#         <tr>
#           <td class="field-index" width="10%">3</td>
#           <td>type_dengue</td>
#           <td>Type dengue</td>
#           <td class="field-type">
#             Text (General)
#
#
#           </td>
#           <td>-</td>
#           <td>
#
#             -
#           </td>
#         </tr>
#
#         <tr>
#           <td class="field-index" width="10%">4</td>
#           <td>number</td>
#           <td>Number</td>
#           <td class="field-type">
#             Text (General)
#
#
#           </td>
#           <td>-</td>
#           <td>
#
#             -
#           </td>
#         </tr>
#
#       </tbody>
#     </table>
#   </div>
#
#   <div class="visible-phone">
#     <table class="table table-condensed">
#       <thead>
#         <tr>
#           <th class="field-index text-center">No.</th>
#           <th>Column</th>
#         </tr>
#       </thead>
#       <tbody>
#
#         <tr>
#           <td class="field-index" >1</td>
#           <td>
#             <div><strong>Name:</strong> year </div>
#             <div><strong>Title:</strong> Year</div>
#             <div>
#               <strong>Type:</strong>
#               <div class="field-type">Datetime (Year)
#
#               <div>&#34;YYYY&#34;</div>
#
#
#             </div>
#             <div>
#               <strong>Unit of Measure:</strong>
#               -
#             </div>
#             <div>
#               <strong>Description:</strong>
#
#               -
#             </div>
#           </td>
#         </tr>
#
#         <tr>
#           <td class="field-index" >2</td>
#           <td>
#             <div><strong>Name:</strong> eweek </div>
#             <div><strong>Title:</strong> Eweek</div>
#             <div>
#               <strong>Type:</strong>
#               <div class="field-type">Numeric (General)
#
#
#             </div>
#             <div>
#               <strong>Unit of Measure:</strong>
#               Week
#             </div>
#             <div>
#               <strong>Description:</strong>
#
#               -
#             </div>
#           </td>
#         </tr>
#
#         <tr>
#           <td class="field-index" >3</td>
#           <td>
#             <div><strong>Name:</strong> type_dengue </div>
#             <div><strong>Title:</strong> Type dengue</div>
#             <div>
#               <strong>Type:</strong>
#               <div class="field-type">Text (General)
#
#
#             </div>
#             <div>
#               <strong>Unit of Measure:</strong>
#               -
#             </div>
#             <div>
#               <strong>Description:</strong>
#
#               -
#             </div>
#           </td>
#         </tr>
#
#         <tr>
#           <td class="field-index" >4</td>
#           <td>
#             <div><strong>Name:</strong> number </div>
#             <div><strong>Title:</strong> Number</div>
#             <div>
#               <strong>Type:</strong>
#               <div class="field-type">Text (General)
#
#
#             </div>
#             <div>
#               <strong>Unit of Measure:</strong>
#               -
#             </div>
#             <div>
#               <strong>Description:</strong>
#
#               -
#             </div>
#           </td>
#         </tr>
#
#       </tbody>
#     </table>
#   </div>
# </div>
#         </div>
#
#         <div class="resource-fields-additional-info">
#           <span class="title">Additional Information</span>
#           <table class="table table-condensed" data-module="table-toggle-more">
#             <tbody>
#               <tr>
#                 <th scope="row">Last updated</th>
#                 <td>September 30, 2019</td>
#               </tr>
#               <tr>
#                 <th scope="row">Created</th>
#                 <td>September 30, 2019</td>
#               </tr>
#               <tr>
#                 <th scope="row">Format</th>
#                 <td>CSV</td>
#               </tr>
#
#                 <tr>
#                   <th scope="row">Coverage</th>
#                   <td>
#
#                       January 1, 2014 to December 31, 2018
#
#                   </td>
#                 </tr>
#
#               <tr>
#                 <th scope="row">Licence</th>
#
#                 <td class="dataset-details"><a href="/open-data-licence" rel="dc:rights">Singapore Open Data Licence</a></td>
#               </tr>
#             </tbody>
#           </table>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
#
#
#
#
# </div>
#
# <section>
#   <div class="container">
#     <h2 class="section-title">About this dataset</h2>
#       <article class="card">
#         <div class="dataset-description">
#
#           <p>This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018.</p>
#         </div>
#         <div class="dataset-metadata">
#
#
# <article class="metadata-card">
#   <table class="table">
#     <tbody>
#
#
#       <tr>
#         <th scope="row">Managed By</th>
#         <td><a href="/dataset?organization=ministry-of-health">Ministry of Health</a></td>
#       </tr>
#
#
#         <tr>
#           <th scope="row">Last Updated</th>
#           <td>September 30, 2019, 10:33 (SGT)</td>
#         </tr>
#
#
#
#         <tr>
#           <th scope="row">Created</th>
#           <td>September 30, 2019, 09:59 (SGT)</td>
#         </tr>
#
#
#
#
#         <tr>
#           <th scope="row">Coverage</th>
#
#
#             <td>January 1, 2014 to December 31, 2018</td>
#
#         </tr>
#
#
#
#         <tr>
#           <th scope="row">Frequency</th>
#           <td>Weekly</td>
#         </tr>
#
#
#
#
#
#
#
#
#
#
#           <tr>
#             <th scope="row">Source(s)</th>
#             <td>Ministry of Health</td>
#           </tr>
#
#
#
#
#
#
#       <tr>
#         <th scope="row">Licence</th>
#         <td><a href="/open-data-licence">Singapore Open Data Licence</a></td>
#       </tr>
#
#
#     </tbody>
#   </table>
# </article>
#         </div>
#       </article>
#   </div>
# </section>
#
#
#
# <section class="similar-datasets">
#   <div class="container">
#     <h2 class="section-title">Similar Datasets</h2>
#     <article class="card similar-datasets-card">
#       <div class="row-flex">
#
#
#         <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#
#
# <article class="card package-card" >
#
#
# <div class="package-card-details">
#
#   <h3 class="package-card-title">
#     <a class="ga-dataset-card-title" data-ga=e7536645-6126-4358-b959-a02b22c6c473 href="/dataset/dengue-clusters">
#       Dengue Clusters
#     </a>
#   </h3>
#
#
#   <small class="package-card-meta text-muted">
#
#     <a class='package-card-organization ga-dataset-card-org'
#       data-ga=national-environment-agency
#       href="/dataset?organization=national-environment-agency">
#       National Environment Agency
#     </a>
#
#     /
#     13 Oct 2019
#   </small>
#
#
#   <p class="package-card-description ga-search-dataset-card-description">Location of dengue cluster</p>
# </div>
#
#
# <div class="resource-formats">
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/KML.svg/>
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/GEOJSON.svg/>
#
# </div>
#
# </article>
#         </div>
#
#         <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#
#
# <article class="card package-card" >
#
#
# <div class="package-card-details">
#
#   <h3 class="package-card-title">
#     <a class="ga-dataset-card-title" data-ga=40c39ea3-ce9f-4c7d-bcd9-fbc2bc9eb320 href="/dataset/dengue-cases">
#       Dengue Cases
#     </a>
#   </h3>
#
#
#   <small class="package-card-meta text-muted">
#
#     <a class='package-card-organization ga-dataset-card-org'
#       data-ga=national-environment-agency
#       href="/dataset?organization=national-environment-agency">
#       National Environment Agency
#     </a>
#
#     /
#     07 Nov 2018
#   </small>
#
#
#   <p class="package-card-description ga-search-dataset-card-description">Dengue Cases in various regions.                   Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days.                   Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.</p>
# </div>
#
#
# <div class="resource-formats">
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/KML.svg/>
#
# </div>
#
# </article>
#         </div>
#
#         <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#
#
# <article class="card package-card" >
#
#
# <div class="package-card-details">
#
#   <h3 class="package-card-title">
#     <a class="ga-dataset-card-title" data-ga=91508e0b-3a36-4a0d-aeb4-d62a0071f65e href="/dataset/dengue-cases-south-west">
#       Dengue (Cases) - South West
#     </a>
#   </h3>
#
#
#   <small class="package-card-meta text-muted">
#
#     <a class='package-card-organization ga-dataset-card-org'
#       data-ga=national-environment-agency
#       href="/dataset?organization=national-environment-agency">
#       National Environment Agency
#     </a>
#
#     /
#     13 Oct 2019
#   </small>
#
#
#   <p class="package-card-description ga-search-dataset-card-description">Dengue cases in southwest region.
# Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days. Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.</p>
# </div>
#
#
# <div class="resource-formats">
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/KML.svg/>
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/GEOJSON.svg/>
#
# </div>
#
# </article>
#         </div>
#
#         <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#
#
# <article class="card package-card" >
#
#
# <div class="package-card-details">
#
#   <h3 class="package-card-title">
#     <a class="ga-dataset-card-title" data-ga=e4e20dd2-d5ca-48df-9400-7b97b7b982fa href="/dataset/dengue-cases-south-east">
#       Dengue (Cases) - South East
#     </a>
#   </h3>
#
#
#   <small class="package-card-meta text-muted">
#
#     <a class='package-card-organization ga-dataset-card-org'
#       data-ga=national-environment-agency
#       href="/dataset?organization=national-environment-agency">
#       National Environment Agency
#     </a>
#
#     /
#     13 Oct 2019
#   </small>
#
#
#   <p class="package-card-description ga-search-dataset-card-description">Dengue cases in southeast region.
# Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days. Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.</p>
# </div>
#
#
# <div class="resource-formats">
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/KML.svg/>
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/GEOJSON.svg/>
#
# </div>
#
# </article>
#         </div>
#
#         <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#
#
# <article class="card package-card" >
#
#
# <div class="package-card-details">
#
#   <h3 class="package-card-title">
#     <a class="ga-dataset-card-title" data-ga=9efcc45e-4f59-4465-b6f5-d5791f70ca56 href="/dataset/dengue-cases-north-east">
#       Dengue (Cases) - North East
#     </a>
#   </h3>
#
#
#   <small class="package-card-meta text-muted">
#
#     <a class='package-card-organization ga-dataset-card-org'
#       data-ga=national-environment-agency
#       href="/dataset?organization=national-environment-agency">
#       National Environment Agency
#     </a>
#
#     /
#     13 Oct 2019
#   </small>
#
#
#   <p class="package-card-description ga-search-dataset-card-description">Dengue cases in north east region.
# Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days. Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.</p>
# </div>
#
#
# <div class="resource-formats">
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/KML.svg/>
#
#
#     <img class="format-icon ga-search-dataset-card-file-icon"
#          src=/images/icons/file_type/GEOJSON.svg/>
#
# </div>
#
# </article>
#         </div>
#
#
#       </div>
#     </article>
#   </div>
# </section>
#
#     </main>
#
#
#
#
#
#     <footer class="site-footer">
#       <div class='container'>
#
#         <div class="row">
#           <div class="col-xs-12 col-md-7 footer-groups">
#             <div class="attribution-group text-left">
#               <h2>Built by</h2>
#               <a href="https://tech.gov.sg">
#                 <img
#                   src="/images/govtech_logo.png"
#                   alt="GovTech"
#                   width="172"
#                   height="40"
#                 >
#               </a><br>
#               <small class="text-muted">
#                 iewil   joelchoo   pallani   yongjun21
#               </small><br><br><br>
#               <div><small>Last updated on October 15, 2019</small></div>
#               <small>&copy; 2017 Government of Singapore</small>
#             </div>
#           </div>
#           <div class="col-xs-12 col-md-3 footer-groups">
#             <h2>Useful Links</h2>
#               <div class="footer-link">
#                 <a class="ga-footer-about" href="/about">About Us</a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-privacy" href="/privacy-and-website-terms">Privacy &amp; Website Terms</a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-odl" href="/open-data-licence">Open Data Licence</a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-developer-guide" href="/developer">Developers</a>
#               </div>
#             </div>
#           <div class="col-xs-12 col-md-2 footer-groups">
#             <h2>Find Us</h2>
#               <div class="footer-link">
#                 <a class="ga-footer-email" href="mailto:feedback@data.gov.sg?Subject=[Data.gov.sg] Feedback">
#                 <img class="footer-site-icon"
#                   src="/images/email_white.png"
#                   title="Email"/>Email
#                 </a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-facebook" href="https://www.facebook.com/opendatasg/">
#                   <img class="footer-site-icon"
#                   src="/images/fb_white.svg"
#                   title="Facebook"/>Facebook
#                 </a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-twitter" href="https://twitter.com/datagovsg">
#                   <img class="footer-site-icon"
#                   src="/images/twitter_white.svg"
#                   title="Twitter"/>Twitter
#                 </a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-medium" href="https://blog.data.gov.sg/">
#                 <img class="footer-site-icon"
#                   src="/images/medium_white.svg"
#                   title="Medium"/>Medium
#                 </a>
#               </div>
#               <div class="footer-link">
#                 <a class="ga-footer-github" href="https://github.com/datagovsg">
#                 <img class="footer-site-icon"
#                   src="/images/github_white.svg"
#                   title="Github"/>Github
#                 </a>
#               </div>
#           </div>
#
#
#
#    <!--      <nav class="footer-links">
#
#         </nav>
#  -->
#
#       </div>
#     </footer>
#
#
#
#
#     <footer class="site-account text-right text-muted">
#       <div class="container">
#         <small>
#
#
#           <a href="/user/login">
#             Log In
#           </a>
#
#         </small>
#       </div>
#     </footer>
#
#
#
#
#
#   <script>document.getElementsByTagName('html')[0].className += ' js';</script>
# <script type="text/javascript" src="/fanstatic/vendor/:version:2019-10-14T11:24:30/jquery.min.js"></script>
# <script type="text/javascript" src="/fanstatic/vendor/:version:2019-10-14T11:24:30/:bundle:jed.min.js;moment-with-locales.js;select2/select2.min.js"></script>
# <script type="text/javascript" src="/fanstatic/base/:version:2019-10-14T11:24:30/:bundle:plugins/jquery.inherit.min.js;plugins/jquery.proxy-all.min.js;plugins/jquery.url-helpers.min.js;plugins/jquery.date-helpers.min.js;plugins/jquery.slug.min.js;plugins/jquery.slug-preview.min.js;plugins/jquery.truncator.min.js;plugins/jquery.masonry.min.js;plugins/jquery.form-warning.min.js;sandbox.min.js;module.min.js;pubsub.min.js;client.min.js;notify.min.js;i18n.min.js;main.min.js"></script>
# <script type="text/javascript" src="/fanstatic/datagovsg-lib/:version:2019-10-14T11:24:40/bootstrap/bootstrap.js"></script>
# <script type="text/javascript" src="/fanstatic/datagovsg-js/:version:2019-10-14T11:42:36.90/snippets/ga-events.min.js"></script></body>
#
#
# </html>

# %% [markdown]
# ### Soupify the Text

# %%
page = response.text

# %% [markdown]
# lxml is a library for processing XML and HTML in Python. We are parsing the data from txt to lxml.

# %%
# if needed: pip install beautifulsoup4 lxml or conda install beautifulsoup4 lxml
from bs4 import BeautifulSoup

soup = BeautifulSoup(page, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <title>The Big Lebowski (1998) - Box Office Mojo</title>
# <style type="text/css">
# table.chart-wide { width: 100%; }
# </style>
# <meta content="the big lebowski, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, gramercy, theatrical summary, theatrical, showtimes, tickets, show times, theaters, playing, weekend box office results, weekly box office, weekly box office, release summary, similar movies, box office mojo" name="keywords"/>
# <meta content="The Big Lebowski summary of box office results, charts and release information and related links." name="description"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
# <script src="/js/jscharts.js" type="text/javascript"></script>
# </head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = '//s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
# <div id="container">
# <div>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     (function() {
#         var gads = document.createElement("script");
#         gads.async = true;
#         gads.type = "text/javascript";
#
#         var useSSL = "https:" == document.location.protocol;
#         gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#         var node = document.getElementsByTagName("script")[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
# <div id="hp_banner">
# <div id="top_links">
# <div style="float: left"><a href="/daily/chart/">Daily Box Office (Sun.)</a> | <a href="/weekend/chart/">Weekend Box Office (Oct. 11–13)</a> | <a href="/movies/?id=joker2019.htm">#1 Movie: 'Joker (2019)'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# <div style="float: right">Updated 10/13/2019 8:31 A.M. Pacific Time</div>
# <div style="clear:both; height: 0px"></div>
# </div>
# </div>
# <div id="header">
# <div id="leaderboard"><script src="//bs.serving-sys.com/Serving/adServer.bs?c=28&amp;cn=display&amp;pli=1073982656&amp;w=728&amp;h=90&amp;ord=1571031723&amp;z=0"></script>
# <noscript>
# <a href="//bs.serving-sys.com/Serving/adServer.bs?cn=brd&amp;pli=1073982656&amp;Page=&amp;Pos=668343950" target="_blank">
# <img border="0" height="90" src="//bs.serving-sys.com/Serving/adServer.bs?c=8&amp;cn=display&amp;pli=1073982656&amp;Page=&amp;Pos=668343950" width="728"/>
# </a>
# </noscript>
# </div>
# <div id="leaderboard"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-1").addService(googletag.pubads().setTargeting("p", "t"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-1"); });
# </script></div> <div id="hp_logo"><a href="/"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a></div>
# <div style="clear:both; height: 0px"></div>
# </div>
# </div>
# <div class="connect_nav">
# <ul>
# <li class="nl_link">
# <a href="http://pro.imdb.com/signup/index.html?rf=mojo_nb_hm&amp;ref_=mojo_nb_hm" target="_blank">
# <img alt="Get industry info at IMDbPro" height="20" src="/images/IMDbPro.png"/>
# </a>
# </li>
# <li class="nl_link">
# <a href="http://twitter.com/boxofficemojo" target="_blank">
# <img alt="Follow us on Twitter" height="18" src="/images/glyphicons-social-32-twitter@2x.png"/>
# </a>
# </li>
# <li class="nl_link">
# <a href="http://facebook.com/boxofficemojo" target="_blank">
# <img alt="Follow us on Facebook" height="18" src="/images/glyphicons-social-31-facebook@2x.png"/>
# </a>
# </li>
# </ul>
# </div>
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# <div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# <form action="/search/q.php" method="POST" name="searchbox">
# <input name="q" style="font-size: 9 pt; font-weight: bold; width: 90px;" type="text"/><br/>
# <input type="submit" value="Search..."/></form>
# </li>
# <li class="nl_section">Features</li>
# <li class="nl_link"><a href="/news/">News</a></li>
# <li class="nl_link"><a href="/schedule/">Release Sched.</a></li>
# <li class="nl_link"><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a></li>
# <li class="nl_section">Box Office</li>
# <li class="nl_link"><a href="/daily/">Daily</a></li>
# <li class="nl_link"><a href="/weekend/">Weekend</a></li>
# <li class="nl_link"><a href="/weekly/">Weekly</a></li>
# <li class="nl_link"><a href="/monthly/">Monthly</a></li>
# <li class="nl_link"><a href="/quarterly/">Quarterly</a></li>
# <li class="nl_link"><a href="/seasonal/">Seasonal</a></li>
# <li class="nl_link"><a href="/yearly/">Yearly</a></li>
# <li class="nl_link"><a href="/alltime/">All Time</a></li>
# <li class="nl_link"><a href="/intl/">International</a></li>
# <li class="nl_section">Indices</li>
# <li class="nl_link"><a href="/studio/">Studios</a></li>
# <li class="nl_link"><a href="/people/">People</a></li>
# <li class="nl_link"><a href="/genres/">Genres</a></li>
# <li class="nl_link"><a href="/franchises/">Franchises</a></li>
# <li class="nl_link"><a href="/showdowns/">Showdowns</a></li>
# <li class="nl_link"><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# <div id="body">
# <table border="0" cellspacing="0" width="878px">
# <tr>
# <td align="right" style="whitespace:nowrap;">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <form action="/adjuster.php" method="POST" name="adjuster">
# <input name="returnURL" type="hidden" value="/movies/?id=biglebowski.htm"/>
# <td valign="center">
# <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
# <select name="ticketyr" size="1" style="font-family: Verdana; font-size: 10pt">
# <option selected="" value="0">Actuals</option>
# <option value="1">Est. Tckts</option>
# <script language="javascript">
#   for(i=2019; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
# <option value="1929">1929</option>
# <option value="1924">1924</option>
# <option value="1910">1910</option>
# </select><input name="Go" style="font-size: 10pt; height: 22" type="submit" value="Go"/>
# </td></form></tr></table>
# </td></tr>
# <!--------------------------Site Body---------------------------------->
# <tr>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr> <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" style="padding-top: 5px;" width="100%"><tr><td align="center" valign="top">
# <a href="/movies/?page=media&amp;id=biglebowski.htm"><img border="1" src="https://m.media-amazon.com/images/M/MV5BMTQ0NjUzMDMyOF5BMl5BanBnXkFtZTgwODA1OTU0MDE@._V1_UY222_CR0,0,150,222_AL.jpg" style="border-color: 000000"/></a> </td>
# <td align="center" valign="top"><br/><font face="Verdana" size="6"><b>The Big Lebowski</b></font><br/><br/>
# <table border="0" cellpadding="0" cellspacing="0"><tr><td>
# <center><table bgcolor="#dcdcdc" border="0" cellpadding="4" cellspacing="1" width="95%"><tr bgcolor="#ffffff"><td align="center" colspan="2"><font size="4">Domestic Total Gross: <b>$17,451,873</b></font><br/><font size="2"><a href="?page=releases&amp;id=biglebowski.htm"><b>Domestic Lifetime Gross: $18,034,458</b></a></font></td></tr><tr bgcolor="#ffffff"><td valign="top">Distributor: <b><a href="/studio/chart/?studio=gramercy.htm">Gramercy</a></b></td><td valign="top">Release Date: <b><nobr><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=1998-03-06&amp;p=.htm">March 6, 1998</a></nobr></b></td></tr><tr bgcolor="#ffffff"><td valign="top">Genre: <b>Crime Comedy</b></td><td valign="top">Runtime: <b>1 hrs. 57 min.</b></td></tr><tr bgcolor="#ffffff"><td valign="top">MPAA Rating: <b>R</b></td><td valign="top">Production Budget: <b>N/A</b></td></tr></table><table border="0" cellpadding="2" cellspacing="0" width="95%">
# <form action="/showtimes/savelocation.php" method="POST" name="movietimesbox">
# <input name="return" type="hidden" value="bymovie|biglebowski.htm"/>
# <tr>
# <td nowrap="" style="padding-top: 10px">
# <a href="http://www.imdb.com/showtimes?ref_=mojo"><img src="/images/mojo_imdb_med.png" style="vertical-align:middle"/></a> <a href="http://www.imdb.com/showtimes?ref_=mojo">Get local showtimes at IMDb</a>
# </td></tr></form></table>
# </center></td>
# </tr></table></td>
# <td align="right"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[300, 250]], "ad-slot-2").addService(googletag.pubads().setTargeting("p", "rh"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-2"); });
# </script></td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="878px">
# <tr><td>
# <ul class="nav_tabs">
# <li class="nav_tab_current"><a href="/movies/?page=main&amp;id=biglebowski.htm">Summary</a></li>
# <li><a href="/movies/?page=weekend&amp;id=biglebowski.htm">Weekend</a></li>
# <li><a href="/movies/?page=weekly&amp;id=biglebowski.htm">Weekly</a></li>
# <li><a href="/movies/?page=releases&amp;id=biglebowski.htm">Releases</a></li>
# <li><a href="/movies/?page=similar&amp;id=biglebowski.htm">Similar Movies</a></li>
# </ul>
# <br/>
# </td></tr>
# <tr><td>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr><td valign="top" width="434px">
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr>
# <td valign="top" width="50%">
# <div class="mp_box">
# <div class="mp_box_tab">Total Lifetime Grosses</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td width="40%"><b>Domestic:</b></td>
# <td align="right" width="35%"> <b>$18,034,458</b></td>
# <td align="right" width="25%">   <b>38.6%</b></td>
# </tr>
# <tr>
# <td width="40%">+ Foreign:</td>
# <td align="right" width="35%"> $28,690,764</td>
# <td align="right" width="25%">   61.4%</td>
# </tr>
# <tr>
# <td colspan="3" width="100%"><hr/></td>
# </tr>
# <tr>
# <td width="40%">= <b>Worldwide:</b></td>
# <td align="right" width="35%"> <b>$46,725,222</b></td>
# <td width="25%"> </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="mp_box">
# <div class="mp_box_tab">Domestic Summary</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="center"><a href="/weekend/chart/?yr=1998&amp;wknd=10&amp;p=.htm">Opening Weekend:</a></td><td> $5,533,844</td></tr>
# <tr>
# <td align="center" colspan="2"><font size="2">(#6 rank, 1,207 theaters, $4,585 average)</font></td></tr>
# <tr>
# <td align="right">% of Total Gross:</td><td> 31.7%</td></tr>
# <tr><td align="right" colspan="2"><font face="Helvetica, Arial, Sans-Serif" size="1"><a href="/movies/?page=weekend&amp;id=biglebowski.htm"><b>&gt; View All 4 Weekends</b></a></font></td></tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>Widest Release:</td>
# <td> 1,235 theaters</td>
# </tr>
# </table>
# </div>
# </div>
# </td>
# <td style="padding-left: 10px;" valign="top"><div class="mp_box">
# <div class="mp_box_tab">The Players</div>
# <div class="mp_box_content">
# <table>
# <tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Director&amp;p=.htm">Director:</a></font></td><td><font size="2"><a href="/people/chart/?view=Director&amp;id=joelcoen.htm">Joel Coen</a></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Writer&amp;p=.htm">Writers:</a></font></td><td><font size="2"><a href="/people/chart/?view=Writer&amp;id=ethancoen.htm">Ethan Coen</a><br/><a href="/people/chart/?view=Writer&amp;id=joelcoen.htm">Joel Coen</a></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Actor&amp;p=.htm">Actors:</a></font></td><td><font size="2"><a href="/people/chart/?view=Actor&amp;id=jeffbridges.htm">Jeff Bridges</a><br/><a href="/people/chart/?view=Actor&amp;id=johngoodman.htm">John Goodman</a><br/><a href="/people/chart/?view=Actor&amp;id=juliannemoore.htm">Julianne Moore</a><br/>Steve Buscemi<br/><a href="/people/chart/?view=Actor&amp;id=philipseymourhoffman.htm">Philip Seymour Hoffman</a><br/>Tara Reid<br/><a href="/people/chart/?view=Actor&amp;id=samelliott.htm">Sam Elliott*</a> <font size="2">(Narrator)</font></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Producer&amp;p=.htm">Producers:</a></font></td><td><font size="2"><a href="/people/chart/?view=Producer&amp;id=timbevan.htm">Tim Bevan</a> <font size="2">(executive producer)</font><br/><a href="/people/chart/?view=Producer&amp;id=ethancoen.htm">Ethan Coen</a><br/><a href="/people/chart/?view=Producer&amp;id=ericfellner.htm">Eric Fellner</a> <font size="2">(executive producer)</font></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Cinematographer&amp;p=.htm"><font size="2">Cinematographer</font>:</a></font></td><td><font size="2"><a href="/people/chart/?view=Cinematographer&amp;id=rogerdeakins.htm">Roger Deakins</a></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Composer&amp;p=.htm">Composer:</a></font></td><td><font size="2"><a href="/people/chart/?view=Composer&amp;id=carterburwell.htm">Carter Burwell</a></font></td></tr><tr><td align="right" colspan="2"><i><small>* Denotes minor role</small></i></td></tr></table></div></div></td>
# </tr></table>
# <div class="mp_box">
# <div class="mp_box_tab">Genres</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr><th>Genre</th>
# <th>Rank</th></tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/genres/chart/?id=blackcomedy.htm">Comedy - Dark/Black</a></font></td>
# <td align="center"><font size="2">33</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/genres/chart/?id=slackerstoner.htm">Slacker / Stoner</a></font></td>
# <td align="center"><font size="2">34</font></td>
# </tr>
# </table></div></div><div class="mp_box">
# <div class="mp_box_tab">Charts</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr><td bgcolor=""><b>Chart</b></td>
# <td align="center"><b>Rank</b></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/domestic.htm">All Time Domestic</a></font></td>
# <td align="center"><font size="2">3,686</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/?yr=1998&amp;p=.htm">Yearly 1998</a></font></td>
# <td align="center"><font size="2">96</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=releasedate&amp;view=opening&amp;yr=1998&amp;p=.htm">Yearly Opening Weekends 1998</a></font></td>
# <td align="center"><font size="2">88</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/mpaarating.htm?rating=R&amp;yr=1998&amp;p=.htm">Yearly R Rated 1998</a></font></td>
# <td align="center"><font size="2">41</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=worldwide&amp;yr=1998&amp;p=.htm">Worldwide Yearly 1998</a></font></td>
# <td align="center"><font size="2">54</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/openingweeks.htm">Opening Weeks</a></font></td>
# <td align="center"><font size="2">3,232</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/">Opening Weekends</a></font></td>
# <td align="center"><font size="2">3,131</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/weekends/smallestdrops.htm?page=SMALLDROPWID&amp;p=.htm">Smallest Drops, All Wide Releases</a></font></td>
# <td align="center"><font size="2">1,690</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2">BOM Users' Grades (1998 Releases)</font></td>
# <td align="center"><font size="2">15</font></td>
# </tr>
# <tr><td><b>Charts (Premier Pass Users Only)</b></td><td align="center"><b>Rank</b></td></tr><tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/domestic.htm?page=14&amp;asof=1998-04-10&amp;p=.htm">Highest All Time Rank (on April 10, 1998)</a></font></td>
# <td align="center"><font size="2">1364</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/?view2=wide&amp;view=domestic&amp;yr=1998&amp;p=.htm">Yearly (Wide) 1998</a></font></td>
# <td align="center"><font size="2">90</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=opening&amp;yr=1998&amp;p=.htm">Yearly Opening Weekends (Wide) 1998</a></font></td>
# <td align="center"><font size="2">91</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/openingweeks.htm?adjust_yr=2019&amp;p=.htm">Opening Weeks Adjusted</a></font></td>
# <td align="center"><font size="2">2,985</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/?adjust_yr=2019&amp;p=.htm">Opening Weekends Adjusted</a></font></td>
# <td align="center"><font size="2">2,904</font></td>
# </tr>
# </table></div></div>
# </td>
# <td width="10px"> </td>
# <td valign="top" width="434px">
# <div class="mp_box">
# <div class="mp_box_tab">Related Stories</div>
# <div class="mp_box_content"><table border="0" cellpadding="5" cellspacing="0" width="100%"><tr bgcolor="#ffff99"><td><font size="2"><a href="/news/?id=2680&amp;p=.htm">2/11/10 2010 Preview: True Grit</a></font></td></tr></table></div></div> <div class="mp_box">
# <div class="mp_box_tab">Related Products</div>
# <div class="mp_box_content"><ul>
# <li><a href="http://www.amazon.com/gp/product/B000A7DVR2?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000A7DVR2">The Big Lebowski (Collector's Edition)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000A7DVR2" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000A7DVY0?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000A7DVY0">The Big Lebowski - Achiever's Edition</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000A7DVY0" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000ASATSU?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000ASATSU">The Coen Brothers Collection</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000ASATSU" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000O179EK?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000O179EK">The Big Lebowski (HD-DVD)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000O179EK" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000O179EK?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000O179EK">The Big Lebowski (HD-DVD)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000O179EK" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B001AEF6CW?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B001AEF6CW">The Big Lebowski (10th Anniv. Limited Edition)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B001AEF6CW" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B001AEF6D6?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B001AEF6D6">The Big Lebowski (10th Anniv. Edition)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B001AEF6D6" style="border:none !important; margin:0px !important;" width="1"/></li>
# </ul></div></div> <object classid="clsid:D27CDB6E-AE6D-11cf-96B8-444553540000" codebase="http://fpdownload.macromedia.com/get/flashplayer/current/swflash.cab" height="150px" id="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" width="400px"> <param name="movie" value="//ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=GetDisplayTemplate"/><param name="quality" value="high"/><param name="bgcolor" value="#FFFFFF"/><param name="allowscriptaccess" value="always"/><embed align="middle" allowscriptaccess="always" bgcolor="#ffffff" height="150px" id="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" name="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" quality="high" src="//ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=GetDisplayTemplate" type="application/x-shockwave-flash" width="400px"/></object> <noscript><a href="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=NoScript">Amazon.com Widgets</a></noscript>
# </td>
# </tr>
# </table>
# <br/>
# </td>
# </tr>
# </table>
# </td></tr></table>
# <div id="hp_footer">
# <div style="padding-bottom: 20px;">
# <div style="margin: 0px 121px; vertical-align: top;">
# <div id="footer_links">
# <ul class="footer_link_list">
# <li><strong>Latest Updates</strong></li>
# <li><a href="/news/?ref=ft">Movie News</a>
# </li><li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# <li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# <li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# <li><a href="/intl/?ref=ft">International Charts</a></li>
# </ul>
# <!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# <ul class="footer_link_list">
# <li><strong>Indices</strong></li>
# <li><a href="/people/?ref=ft">People</a></li>
# <li><a href="/genres/?ref=ft">Genres</a></li>
# <li><a href="/franchises/?ref=ft">Franchises</a></li>
# <li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# </ul>
# <ul class="footer_link_list">
# <li><strong>Other</strong></li>
# <li><a href="/about/?ref=ft">About This Site</a></li>
# <li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# </ul>
# </div>
# <div id="copyright">
# <a href="/?ref=ft"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a><br/>
# <p>An <a href="http://imdb.com/"><img alt="IMDb" height="16" src="/img/misc/IMDbSm.png" valign="middle" width="34"/></a> company<br/><br/></p>
# <p>© <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# </div>
# </div>
# <div style="clear:both;">
# <div>
# <script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-3").addService(googletag.pubads().setTargeting("p", "b"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-3"); });
# </script></div>
# </div>
# </div>
# </div>
# <!-- Page generated in 0.09 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6034961&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# </tr></table></div></div></div></body>
# </html>

# %% [markdown]
# ### Prettify the Soup

# %% [markdown]
# A webpage can be thought of as a tree of elements, there is the 'body', which would contain a few 'divs' and each of those 'divs' can in turn contain 'divs' and other elements. A Soup object contains this tree. The prettify() method will turn a Beautiful Soup tree into a nicely formatted Unicode string, with each HTML/XML tag on its own line.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en_GB">
#  <head>
#   <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2019-10-14T11:24:30/html5.min.js"></script><![endif]-->
#   <link href="/fanstatic/vendor/:version:2019-10-14T11:24:30/select2/select2.css" rel="stylesheet" type="text/css"/>
#   <link href="/fanstatic/datagovsg-css/:version:2019-10-14T11:42:38.32/datagovsg.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/fanstatic/datagovsg-css/:version:2019-10-14T11:42:38.32/package/read.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/fanstatic/datagovsg-css/:version:2019-10-14T11:42:38.32/package/snippets/resource_item_fields.min.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases-Data.gov.sg
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="ckan " name="generator"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport" user-scalable="no"/>
#   <meta content="This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018." name="description"/>
#   <meta content="#113355" name="theme-color"/>
#   <meta content="Data.gov.sg" name="application-name"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@datagovsg" name="twitter:site"/>
#   <meta content="Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases-Data.gov.sg
#       " name="twitter:title"/>
#   <meta content="This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018." name="twitter:description"/>
#   <meta content="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases" name="twitter:url"/>
#   <meta content="https://data.gov.sg/images/thumbnail.png" name="twitter:image:src"/>
#   <meta content="Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases-Data.gov.sg
#       " property="og:title"/>
#   <meta content="This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018." property="og:description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases" property="og:url"/>
#   <meta content="https://data.gov.sg/images/thumbnail.png" property="og:image"/>
#   <meta content="Data.gov.sg" property="og:site_name"/>
#   <meta content="Data.gov.sg" name="apple-mobile-web-app-title"/>
#   <meta content="#113355" name="msapplication-TileColor"/>
#   <meta content="images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link color="#223344" href="/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/images/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#   <link href="/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/images/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <script>
#    // Check if script is being ran from Iframe within data.gov.sg.
#       // This prevents dobule counting in Google Analytics tracking when page views are
#       // triggered twice due to embedding of iframe. This allows us to continue tracking
#       // users who are properly embedding the charts.
#       nodeName = window.frameElement ? window.frameElement.nodeName : 'default'
#       if (!(window.location.hostname.indexOf("data.gov.sg") > -1 && nodeName == "IFRAME")) {
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-64941664-1', 'auto');
#         ga('send', 'pageview');
#
#         window.onload = function () {
#           //track resource downloads
#           document.body.addEventListener('click', function(event) {
#             var element = findElWithClass(event);
#             if (element !== null && typeof element.className == "string"){
#               var classes = element.className.split(' ');
#               for (var event_type in ga_events) {
#                 if (classes.indexOf(event_type) > -1 ) {
#                   var eventCategory = ga_events[event_type].eventCategory;
#                   var eventAction = ga_events[event_type].eventAction;
#                   var eventLabel = element.getAttribute("data-ga") + ": " + window.location.href;
#
#                   if (event_type == "ga-dataset-download") {
#                     eventLabel = element.getAttribute("data-ga");
#                   }
#                   ga('send', 'event', eventCategory, eventAction, eventLabel);
#                 }
#               }
#             }
#           });
#         };
#       }
#
#       function findElWithClass(el) {
#         if (el.target) {
#           el = el.target;
#           while (el) {
#             if (typeof el.className == "string"){
#               var classes = el.className.split(' ');
#               for (var event_type in ga_events) {
#                 if (classes.indexOf(event_type) > -1 ) {
#                   return el;
#                 }
#               }
#             }
#             el = el.parentNode;
#           }
#           return null;
#         }
#       }
#   </script>
#  </head>
#  <body>
#   <nav class="site-nav">
#    <div class="container">
#     <a href="/">
#      <img alt="Data.gov.sg" class="site-logo" src="/images/logo.svg" title="Data.gov.sg"/>
#     </a>
#     <a class="site-title" href="/">
#      Data.gov.sg
#     </a>
#     <div class="flex-spacer">
#     </div>
#     <a class="site-link ga-nav-topic-dropdown" data-toggle="collapse" href=".topic-collapse">
#      Topics
#      <span class="caret">
#      </span>
#     </a>
#     <a class="site-link ga-nav-blog" href="https://blog.data.gov.sg">
#      Blog
#     </a>
#     <a class="site-link ga-nav-developers" href="/developer">
#      Developers
#     </a>
#     <a class="site-link ga-nav-request" href="https://github.com/datagovsg/datagovsg-datasets/issues/new?title=Dataset%20request:%20%3Cdataset%20title%3E">
#      Data Request
#     </a>
#    </div>
#   </nav>
#   <div class="collapse topic-collapse">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Economy" href="/group/economy">
#        <img class="hover-on" src="/images/group_icons/active/economy.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/economy.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Economy
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Education" href="/group/education">
#        <img class="hover-on" src="/images/group_icons/active/education.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/education.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Education
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Environment" href="/group/environment">
#        <img class="hover-on" src="/images/group_icons/active/environment.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/environment.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Environment
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Finance" href="/group/finance">
#        <img class="hover-on" src="/images/group_icons/active/finance.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/finance.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Finance
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Health" href="/group/health">
#        <img class="hover-on" src="/images/group_icons/active/health.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/health.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Health
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Infrastructure" href="/group/infrastructure">
#        <img class="hover-on" src="/images/group_icons/active/infrastructure.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/infrastructure.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Infrastructure
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Society" href="/group/society">
#        <img class="hover-on" src="/images/group_icons/active/society.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/society.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Society
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Technology" href="/group/technology">
#        <img class="hover-on" src="/images/group_icons/active/technology.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/technology.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Technology
#         </small>
#        </h5>
#       </a>
#      </div>
#      <div class="col-xs-4 col-sm-fifth col-sm-ninth">
#       <a class="topic-link ga-nav-topic-selector" data-ga="Transport" href="/group/transport">
#        <img class="hover-on" src="/images/group_icons/active/transport.svg"/>
#        <img class="hover-off" src="/images/group_icons/inactive/transport.svg"/>
#        <h5 class="topic-title">
#         <small>
#          Transport
#         </small>
#        </h5>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <header class="site-header" style="background-image: url()">
#   </header>
#   <main class="site-main">
#    <div class="header-div">
#     <div class="container">
#      <div class="package-title-section">
#       <h2 class="package-title">
#        Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases
#       </h2>
#       <div class="package-title-buttons">
#        <a class="btn datagovsg-btn btn-right btn-orange ga-dataset-download" data-ga="f4c6643f-5b70-406e-a631-1f96e0b90712" href="/dataset/f4c6643f-5b70-406e-a631-1f96e0b90712/download" role="button">
#         <img class="button-icon" src="/images/icons/Download.svg"/>
#         Download
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="dataset-resource-views">
#     <div class="resource-views-header">
#      <div class="resource-selector-header">
#       FILES IN THIS DATASET
#      </div>
#     </div>
#     <div class="resource-views-body">
#      <div class="resource-selector-container">
#       <ul class="resource-selector nav hidden-xs">
#        <li class="active">
#         <a class="ga-dataset-resource-selector" href="/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4">
#          Weekly Number of Dengue and Dengue Haemorrhagic Fever Cases
#          <div>
#           <img class="format-icon" src="/images/icons/file_type/CSV.svg/"/>
#          </div>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="resource-detail-container">
#       <div class="resource-detail container-fluid">
#        <div class="resource-controls-mobile">
#        </div>
#        <div class="resource-controls">
#         <span>
#          Views:
#         </span>
#         <a class="view-tab ga-dataset-resource-view-selector active table" data-ga="Table" href="/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases?view_id=40a6c1fa-842c-420e-ab09-1676a24b2729&amp;resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4">
#          <div>
#          </div>
#          <img class="active" src="/images/icons/resource_view_selectors/active/table.svg"/>
#          <img class="inactive" src="/images/icons/resource_view_selectors/inactive/table.svg"/>
#          <img class="inactive hover" src="/images/icons/resource_view_selectors/hover/table.svg"/>
#         </a>
#         <div class="resource-embed-container">
#          <button class="btn datagovsg-btn btn-right btn-blue desktop-only ga-dataset-data-api" data-ga="c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4" data-target="#dataAPIModal" data-toggle="modal">
#           <img class="button-icon" src="/images/icons/Data_API.svg"/>
#           Data API
#          </button>
#          <!-- <div class="modal" id="dataAPIModal"> -->
#          <div aria-labelledby="myModalLabel" class="modal" id="dataAPIModal" role="dialog" tabindex="-1">
#           <div class="modal-dialog" role="document">
#            <div class="modal-content">
#             <div class="modal-header">
#              <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#               <span aria-hidden="true">
#                ×
#               </span>
#              </button>
#              <h4 class="modal-title" id="myModalLabel">
#               View Embedding Instructions
#              </h4>
#             </div>
#             <div class="modal-body">
#              <div class="accordion">
#               <div class="accordion-group">
#                <div class="accordion-heading">
#                 <a class="accordion-toggle" data-parent="accordion2" data-toggle="collapse" href="#collapse-endpoints">
#                  Endpoints »
#                 </a>
#                </div>
#                <div class="in accordion-body collapse" id="collapse-endpoints">
#                 <div class="accordion-inner">
#                  <p>
#                   The Data API can be accessed via the following actions of the CKAN action API.
#                  </p>
#                  <table class="table-condensed table-striped table-bordered">
#                   <thead>
#                   </thead>
#                   <tbody>
#                    <tr>
#                     <th scope="row">
#                      Query
#                     </th>
#                     <td>
#                      <code>
#                       https://data.gov.sg/api/action/datastore_search
#                      </code>
#                     </td>
#                    </tr>
#                   </tbody>
#                  </table>
#                 </div>
#                </div>
#               </div>
#               <div class="accordion-group">
#                <div class="accordion-heading">
#                 <a class="accordion-toggle" data-parent="accordion2" data-toggle="collapse" href="#collapse-querying">
#                  Querying »
#                 </a>
#                </div>
#                <div class="collapse accordion-body in" id="collapse-querying">
#                 <div class="accordion-inner">
#                  <strong>
#                   Query example (first 5 results)
#                  </strong>
#                  <p>
#                   <code>
#                    <a href="https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&amp;limit=5" target="_blank">
#                     https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&amp;limit=5
#                    </a>
#                   </code>
#                  </p>
#                  <strong>
#                   Query example (results containing 'jones')
#                  </strong>
#                  <p>
#                   <code>
#                    <a href="https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&amp;q=jones" target="_blank">
#                     https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&amp;q=jones
#                    </a>
#                   </code>
#                  </p>
#                 </div>
#                </div>
#               </div>
#               <div class="accordion-group">
#                <div class="accordion-heading">
#                 <a class="accordion-toggle" data-parent="accordion2" data-toggle="collapse" href="#collapse-javascript">
#                  Example: Javascript »
#                 </a>
#                </div>
#                <div class="accordion-body collapse" id="collapse-javascript">
#                 <div class="accordion-inner">
#                  <p>
#                   A simple ajax (JSONP) request to the data API using jQuery.
#                  </p>
#                  <pre>
# var data = {
#   resource_id: 'c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4', // the resource id
#   limit: 5, // get 5 results
#   q: 'jones' // query for 'jones'
# };
# $.ajax({
#   url: 'https://data.gov.sg/api/action/datastore_search',
#   data: data,
#   dataType: 'jsonp',
#   success: function(data) {
#     alert('Total results found: ' + data.result.total)
#   }
# });
#                 </pre>
#                 </div>
#                </div>
#               </div>
#               <div class="accordion-group">
#                <div class="accordion-heading">
#                 <a class="accordion-toggle" data-parent="accordion2" data-toggle="collapse" href="#collapse-python">
#                  Example: Python »
#                 </a>
#                </div>
#                <div class="accordion-body collapse" id="collapse-python">
#                 <div class="accordion-inner">
#                  <pre>
# import urllib
# url = 'https://data.gov.sg/api/action/datastore_search?resource_id=c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4&amp;limit=5&amp;q=title:jones'
# fileobj = urllib.urlopen(url)
# print fileobj.read()
#                 </pre>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- </div> -->
#          <button class="btn datagovsg-btn btn-right btn-blue ga-dataset-embed-chart" data-ga="c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4" data-target="#embedModal" data-toggle="modal">
#           <img class="button-icon" src="/images/icons/Embed.svg"/>
#           Embed Chart
#          </button>
#          <div aria-labelledby="myModalLabel" class="modal" id="embedModal" role="dialog" tabindex="-1">
#           <div class="modal-dialog" role="document">
#            <div class="modal-content">
#             <div class="modal-header">
#              <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#               <span aria-hidden="true">
#                ×
#               </span>
#              </button>
#              <h4 class="modal-title" id="myModalLabel">
#               View Embedding Instructions
#              </h4>
#             </div>
#             <div class="modal-body">
#              <p>
#               Copy the following html into your webpage to embed this view
#              </p>
#              <code class="language-html well" data-lage="html">
#               &lt;iframe
#                       width="600"
#                       height="400"
#                       src="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases/resource/c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4/view/40a6c1fa-842c-420e-ab09-1676a24b2729"
#                       frameBorder="0"&gt;
#                       &lt;/iframe&gt;
#              </code>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="resource-view table-view" id="view-40a6c1fa-842c-420e-ab09-1676a24b2729">
#         <iframe frameborder="0" src="https://data.gov.sg/dataset/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases/resource/c6db5eb2-6daf-4d3b-b571-7bc16c8f03c4/view/40a6c1fa-842c-420e-ab09-1676a24b2729">
#         </iframe>
#        </div>
#        <div class="module-content">
#         <div class="resource-description">
#          <p>
#           This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018.
#          </p>
#         </div>
#         <div class="resource-item-fields">
#          <span class="title">
#           Columns
#          </span>
#          <div class="resource-fields">
#           <div class="hidden-phone">
#            <table class="table table-condensed">
#             <col class="field-index"/>
#             <col class="field-name"/>
#             <col class="field-title"/>
#             <col class="field-type"/>
#             <col class="field-units"/>
#             <col class="field-desc"/>
#             <thead>
#              <tr>
#               <th class="field-index">
#                No.
#               </th>
#               <th class="field-name">
#                Name
#               </th>
#               <th class="field-title">
#                Title
#               </th>
#               <th class="field-type">
#                Type
#               </th>
#               <th class="field-units">
#                Unit of Measure
#               </th>
#               <th class="field-desc">
#                Description
#               </th>
#              </tr>
#             </thead>
#             <tbody>
#              <tr>
#               <td class="field-index" width="10%">
#                1
#               </td>
#               <td>
#                year
#               </td>
#               <td>
#                Year
#               </td>
#               <td class="field-type">
#                Datetime (Year)
#                <br/>
#                "YYYY"
#               </td>
#               <td>
#                -
#               </td>
#               <td>
#                -
#               </td>
#              </tr>
#              <tr>
#               <td class="field-index" width="10%">
#                2
#               </td>
#               <td>
#                eweek
#               </td>
#               <td>
#                Eweek
#               </td>
#               <td class="field-type">
#                Numeric (General)
#               </td>
#               <td>
#                Week
#               </td>
#               <td>
#                -
#               </td>
#              </tr>
#              <tr>
#               <td class="field-index" width="10%">
#                3
#               </td>
#               <td>
#                type_dengue
#               </td>
#               <td>
#                Type dengue
#               </td>
#               <td class="field-type">
#                Text (General)
#               </td>
#               <td>
#                -
#               </td>
#               <td>
#                -
#               </td>
#              </tr>
#              <tr>
#               <td class="field-index" width="10%">
#                4
#               </td>
#               <td>
#                number
#               </td>
#               <td>
#                Number
#               </td>
#               <td class="field-type">
#                Text (General)
#               </td>
#               <td>
#                -
#               </td>
#               <td>
#                -
#               </td>
#              </tr>
#             </tbody>
#            </table>
#           </div>
#           <div class="visible-phone">
#            <table class="table table-condensed">
#             <thead>
#              <tr>
#               <th class="field-index text-center">
#                No.
#               </th>
#               <th>
#                Column
#               </th>
#              </tr>
#             </thead>
#             <tbody>
#              <tr>
#               <td class="field-index">
#                1
#               </td>
#               <td>
#                <div>
#                 <strong>
#                  Name:
#                 </strong>
#                 year
#                </div>
#                <div>
#                 <strong>
#                  Title:
#                 </strong>
#                 Year
#                </div>
#                <div>
#                 <strong>
#                  Type:
#                 </strong>
#                 <div class="field-type">
#                  Datetime (Year)
#                  <div>
#                   "YYYY"
#                  </div>
#                 </div>
#                 <div>
#                  <strong>
#                   Unit of Measure:
#                  </strong>
#                  -
#                 </div>
#                 <div>
#                  <strong>
#                   Description:
#                  </strong>
#                  -
#                 </div>
#                </div>
#               </td>
#              </tr>
#              <tr>
#               <td class="field-index">
#                2
#               </td>
#               <td>
#                <div>
#                 <strong>
#                  Name:
#                 </strong>
#                 eweek
#                </div>
#                <div>
#                 <strong>
#                  Title:
#                 </strong>
#                 Eweek
#                </div>
#                <div>
#                 <strong>
#                  Type:
#                 </strong>
#                 <div class="field-type">
#                  Numeric (General)
#                 </div>
#                 <div>
#                  <strong>
#                   Unit of Measure:
#                  </strong>
#                  Week
#                 </div>
#                 <div>
#                  <strong>
#                   Description:
#                  </strong>
#                  -
#                 </div>
#                </div>
#               </td>
#              </tr>
#              <tr>
#               <td class="field-index">
#                3
#               </td>
#               <td>
#                <div>
#                 <strong>
#                  Name:
#                 </strong>
#                 type_dengue
#                </div>
#                <div>
#                 <strong>
#                  Title:
#                 </strong>
#                 Type dengue
#                </div>
#                <div>
#                 <strong>
#                  Type:
#                 </strong>
#                 <div class="field-type">
#                  Text (General)
#                 </div>
#                 <div>
#                  <strong>
#                   Unit of Measure:
#                  </strong>
#                  -
#                 </div>
#                 <div>
#                  <strong>
#                   Description:
#                  </strong>
#                  -
#                 </div>
#                </div>
#               </td>
#              </tr>
#              <tr>
#               <td class="field-index">
#                4
#               </td>
#               <td>
#                <div>
#                 <strong>
#                  Name:
#                 </strong>
#                 number
#                </div>
#                <div>
#                 <strong>
#                  Title:
#                 </strong>
#                 Number
#                </div>
#                <div>
#                 <strong>
#                  Type:
#                 </strong>
#                 <div class="field-type">
#                  Text (General)
#                 </div>
#                 <div>
#                  <strong>
#                   Unit of Measure:
#                  </strong>
#                  -
#                 </div>
#                 <div>
#                  <strong>
#                   Description:
#                  </strong>
#                  -
#                 </div>
#                </div>
#               </td>
#              </tr>
#             </tbody>
#            </table>
#           </div>
#          </div>
#         </div>
#         <div class="resource-fields-additional-info">
#          <span class="title">
#           Additional Information
#          </span>
#          <table class="table table-condensed" data-module="table-toggle-more">
#           <tbody>
#            <tr>
#             <th scope="row">
#              Last updated
#             </th>
#             <td>
#              September 30, 2019
#             </td>
#            </tr>
#            <tr>
#             <th scope="row">
#              Created
#             </th>
#             <td>
#              September 30, 2019
#             </td>
#            </tr>
#            <tr>
#             <th scope="row">
#              Format
#             </th>
#             <td>
#              CSV
#             </td>
#            </tr>
#            <tr>
#             <th scope="row">
#              Coverage
#             </th>
#             <td>
#              January 1, 2014 to December 31, 2018
#             </td>
#            </tr>
#            <tr>
#             <th scope="row">
#              Licence
#             </th>
#             <td class="dataset-details">
#              <a href="/open-data-licence" rel="dc:rights">
#               Singapore Open Data Licence
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <section>
#     <div class="container">
#      <h2 class="section-title">
#       About this dataset
#      </h2>
#      <article class="card">
#       <div class="dataset-description">
#        <p>
#         This table gives the weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018.
#        </p>
#       </div>
#       <div class="dataset-metadata">
#        <article class="metadata-card">
#         <table class="table">
#          <tbody>
#           <tr>
#            <th scope="row">
#             Managed By
#            </th>
#            <td>
#             <a href="/dataset?organization=ministry-of-health">
#              Ministry of Health
#             </a>
#            </td>
#           </tr>
#           <tr>
#            <th scope="row">
#             Last Updated
#            </th>
#            <td>
#             September 30, 2019, 10:33 (SGT)
#            </td>
#           </tr>
#           <tr>
#            <th scope="row">
#             Created
#            </th>
#            <td>
#             September 30, 2019, 09:59 (SGT)
#            </td>
#           </tr>
#           <tr>
#            <th scope="row">
#             Coverage
#            </th>
#            <td>
#             January 1, 2014 to December 31, 2018
#            </td>
#           </tr>
#           <tr>
#            <th scope="row">
#             Frequency
#            </th>
#            <td>
#             Weekly
#            </td>
#           </tr>
#           <tr>
#            <th scope="row">
#             Source(s)
#            </th>
#            <td>
#             Ministry of Health
#            </td>
#           </tr>
#           <tr>
#            <th scope="row">
#             Licence
#            </th>
#            <td>
#             <a href="/open-data-licence">
#              Singapore Open Data Licence
#             </a>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </article>
#       </div>
#      </article>
#     </div>
#    </section>
#    <section class="similar-datasets">
#     <div class="container">
#      <h2 class="section-title">
#       Similar Datasets
#      </h2>
#      <article class="card similar-datasets-card">
#       <div class="row-flex">
#        <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#         <article class="card package-card">
#          <div class="package-card-details">
#           <h3 class="package-card-title">
#            <a class="ga-dataset-card-title" data-ga="e7536645-6126-4358-b959-a02b22c6c473" href="/dataset/dengue-clusters">
#             Dengue Clusters
#            </a>
#           </h3>
#           <small class="package-card-meta text-muted">
#            <a class="package-card-organization ga-dataset-card-org" data-ga="national-environment-agency" href="/dataset?organization=national-environment-agency">
#             National Environment Agency
#            </a>
#            /
#     13 Oct 2019
#           </small>
#           <p class="package-card-description ga-search-dataset-card-description">
#            Location of dengue cluster
#           </p>
#          </div>
#          <div class="resource-formats">
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/KML.svg/"/>
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/GEOJSON.svg/"/>
#          </div>
#         </article>
#        </div>
#        <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#         <article class="card package-card">
#          <div class="package-card-details">
#           <h3 class="package-card-title">
#            <a class="ga-dataset-card-title" data-ga="40c39ea3-ce9f-4c7d-bcd9-fbc2bc9eb320" href="/dataset/dengue-cases">
#             Dengue Cases
#            </a>
#           </h3>
#           <small class="package-card-meta text-muted">
#            <a class="package-card-organization ga-dataset-card-org" data-ga="national-environment-agency" href="/dataset?organization=national-environment-agency">
#             National Environment Agency
#            </a>
#            /
#     07 Nov 2018
#           </small>
#           <p class="package-card-description ga-search-dataset-card-description">
#            Dengue Cases in various regions.                   Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days.                   Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.
#           </p>
#          </div>
#          <div class="resource-formats">
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/KML.svg/"/>
#          </div>
#         </article>
#        </div>
#        <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#         <article class="card package-card">
#          <div class="package-card-details">
#           <h3 class="package-card-title">
#            <a class="ga-dataset-card-title" data-ga="91508e0b-3a36-4a0d-aeb4-d62a0071f65e" href="/dataset/dengue-cases-south-west">
#             Dengue (Cases) - South West
#            </a>
#           </h3>
#           <small class="package-card-meta text-muted">
#            <a class="package-card-organization ga-dataset-card-org" data-ga="national-environment-agency" href="/dataset?organization=national-environment-agency">
#             National Environment Agency
#            </a>
#            /
#     13 Oct 2019
#           </small>
#           <p class="package-card-description ga-search-dataset-card-description">
#            Dengue cases in southwest region.
# Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days. Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.
#           </p>
#          </div>
#          <div class="resource-formats">
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/KML.svg/"/>
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/GEOJSON.svg/"/>
#          </div>
#         </article>
#        </div>
#        <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#         <article class="card package-card">
#          <div class="package-card-details">
#           <h3 class="package-card-title">
#            <a class="ga-dataset-card-title" data-ga="e4e20dd2-d5ca-48df-9400-7b97b7b982fa" href="/dataset/dengue-cases-south-east">
#             Dengue (Cases) - South East
#            </a>
#           </h3>
#           <small class="package-card-meta text-muted">
#            <a class="package-card-organization ga-dataset-card-org" data-ga="national-environment-agency" href="/dataset?organization=national-environment-agency">
#             National Environment Agency
#            </a>
#            /
#     13 Oct 2019
#           </small>
#           <p class="package-card-description ga-search-dataset-card-description">
#            Dengue cases in southeast region.
# Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days. Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.
#           </p>
#          </div>
#          <div class="resource-formats">
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/KML.svg/"/>
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/GEOJSON.svg/"/>
#          </div>
#         </article>
#        </div>
#        <div class="package-card">
#         <!-- <div class="col-sm-6 col-md-4"> -->
#         <article class="card package-card">
#          <div class="package-card-details">
#           <h3 class="package-card-title">
#            <a class="ga-dataset-card-title" data-ga="9efcc45e-4f59-4465-b6f5-d5791f70ca56" href="/dataset/dengue-cases-north-east">
#             Dengue (Cases) - North East
#            </a>
#           </h3>
#           <small class="package-card-meta text-muted">
#            <a class="package-card-organization ga-dataset-card-org" data-ga="national-environment-agency" href="/dataset?organization=national-environment-agency">
#             National Environment Agency
#            </a>
#            /
#     13 Oct 2019
#           </small>
#           <p class="package-card-description ga-search-dataset-card-description">
#            Dengue cases in north east region.
# Based on notified dengue cases and mosquito breeding habitats detected in the last 14 days. Information on dengue cases is provisional and is subject to changes due to epidemiological investigation findings.
#           </p>
#          </div>
#          <div class="resource-formats">
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/KML.svg/"/>
#           <img class="format-icon ga-search-dataset-card-file-icon" src="/images/icons/file_type/GEOJSON.svg/"/>
#          </div>
#         </article>
#        </div>
#       </div>
#      </article>
#     </div>
#    </section>
#   </main>
#   <footer class="site-footer">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12 col-md-7 footer-groups">
#       <div class="attribution-group text-left">
#        <h2>
#         Built by
#        </h2>
#        <a href="https://tech.gov.sg">
#         <img alt="GovTech" height="40" src="/images/govtech_logo.png" width="172"/>
#        </a>
#        <br/>
#        <small class="text-muted">
#         iewil   joelchoo   pallani   yongjun21
#        </small>
#        <br/>
#        <br/>
#        <br/>
#        <div>
#         <small>
#          Last updated on October 15, 2019
#         </small>
#        </div>
#        <small>
#         © 2017 Government of Singapore
#        </small>
#       </div>
#      </div>
#      <div class="col-xs-12 col-md-3 footer-groups">
#       <h2>
#        Useful Links
#       </h2>
#       <div class="footer-link">
#        <a class="ga-footer-about" href="/about">
#         About Us
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-privacy" href="/privacy-and-website-terms">
#         Privacy &amp; Website Terms
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-odl" href="/open-data-licence">
#         Open Data Licence
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-developer-guide" href="/developer">
#         Developers
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-md-2 footer-groups">
#       <h2>
#        Find Us
#       </h2>
#       <div class="footer-link">
#        <a class="ga-footer-email" href="mailto:feedback@data.gov.sg?Subject=[Data.gov.sg] Feedback">
#         <img class="footer-site-icon" src="/images/email_white.png" title="Email"/>
#         Email
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-facebook" href="https://www.facebook.com/opendatasg/">
#         <img class="footer-site-icon" src="/images/fb_white.svg" title="Facebook"/>
#         Facebook
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-twitter" href="https://twitter.com/datagovsg">
#         <img class="footer-site-icon" src="/images/twitter_white.svg" title="Twitter"/>
#         Twitter
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-medium" href="https://blog.data.gov.sg/">
#         <img class="footer-site-icon" src="/images/medium_white.svg" title="Medium"/>
#         Medium
#        </a>
#       </div>
#       <div class="footer-link">
#        <a class="ga-footer-github" href="https://github.com/datagovsg">
#         <img class="footer-site-icon" src="/images/github_white.svg" title="Github"/>
#         Github
#        </a>
#       </div>
#      </div>
#      <!--      <nav class="footer-links">
#
#         </nav>
#  -->
#     </div>
#     <footer class="site-account text-right text-muted">
#      <div class="container">
#       <small>
#        <a href="/user/login">
#         Log In
#        </a>
#       </small>
#      </div>
#     </footer>
#     <script>
#      document.getElementsByTagName('html')[0].className += ' js';
#     </script>
#     <script src="/fanstatic/vendor/:version:2019-10-14T11:24:30/jquery.min.js" type="text/javascript">
#     </script>
#     <script src="/fanstatic/vendor/:version:2019-10-14T11:24:30/:bundle:jed.min.js;moment-with-locales.js;select2/select2.min.js" type="text/javascript">
#     </script>
#     <script src="/fanstatic/base/:version:2019-10-14T11:24:30/:bundle:plugins/jquery.inherit.min.js;plugins/jquery.proxy-all.min.js;plugins/jquery.url-helpers.min.js;plugins/jquery.date-helpers.min.js;plugins/jquery.slug.min.js;plugins/jquery.slug-preview.min.js;plugins/jquery.truncator.min.js;plugins/jquery.masonry.min.js;plugins/jquery.form-warning.min.js;sandbox.min.js;module.min.js;pubsub.min.js;client.min.js;notify.min.js;i18n.min.js;main.min.js" type="text/javascript">
#     </script>
#     <script src="/fanstatic/datagovsg-lib/:version:2019-10-14T11:24:40/bootstrap/bootstrap.js" type="text/javascript">
#     </script>
#     <script src="/fanstatic/datagovsg-js/:version:2019-10-14T11:42:36.90/snippets/ga-events.min.js" type="text/javascript">
#     </script>
#    </div>
#   </footer>
#  </body>
# </html>

# %% [markdown]
# ## Beautiful Soup - Find & Find_All

# %% [markdown]
# ### `soup.find()`

# %% [markdown]
# * `soup.find()` is the most common function we will use from this package.
# * Let's try out some common variations of `soup.find()`
#
# * `soup.find()` returns the first matched tag it finds.
# * It searches the entire tree.
#
# * Search for a type of tag by using the tag as a string argument ('body','div','p','a')

# %%
soup.find('a') # "a" tag is for hyperlink
# Out:
# <a href="/daily/chart/">Daily Box Office (Sun.)</a>

# %%
# Equivalently:
soup.a
# Out:
# <a href="/daily/chart/">Daily Box Office (Sun.)</a>

# %%
# Prettier:
print(soup.a.prettify())
# Out:
# <a href="/daily/chart/">
#  Daily Box Office (Sun.)
# </a>

# %% [markdown]
# Here's how you can find the next one.

# %%
soup.find('a').findNextSibling()
# Out:
# <a href="/weekend/chart/">Weekend Box Office (Oct. 11–13)</a>

# %% [markdown]
# ### `soup.find_all()`

# %% [markdown]
# `soup.find_all()` returns a list of all matches

# %%
len(soup.find_all('a'))
# Out:
# 100

# %%
for link in soup.find_all('a'): 
    print(link)
# Out:
# <a href="/daily/chart/">Daily Box Office (Sun.)</a>
# <a href="/weekend/chart/">Weekend Box Office (Oct. 11–13)</a>
# <a href="/movies/?id=joker2019.htm">#1 Movie: 'Joker (2019)'</a>
# <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a>
# <a href="//bs.serving-sys.com/Serving/adServer.bs?cn=brd&amp;pli=1073982656&amp;Page=&amp;Pos=668343950" target="_blank">
# <img border="0" height="90" src="//bs.serving-sys.com/Serving/adServer.bs?c=8&amp;cn=display&amp;pli=1073982656&amp;Page=&amp;Pos=668343950" width="728"/>
# </a>
# <a href="/"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a>
# <a href="http://pro.imdb.com/signup/index.html?rf=mojo_nb_hm&amp;ref_=mojo_nb_hm" target="_blank">
# <img alt="Get industry info at IMDbPro" height="20" src="/images/IMDbPro.png"/>
# </a>
# <a href="http://twitter.com/boxofficemojo" target="_blank">
# <img alt="Follow us on Twitter" height="18" src="/images/glyphicons-social-32-twitter@2x.png"/>
# </a>
# <a href="http://facebook.com/boxofficemojo" target="_blank">
# <img alt="Follow us on Facebook" height="18" src="/images/glyphicons-social-31-facebook@2x.png"/>
# </a>
# <a href="/news/">News</a>
# <a href="/schedule/">Release Sched.</a>
# <a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a>
# <a href="/daily/">Daily</a>
# <a href="/weekend/">Weekend</a>
# <a href="/weekly/">Weekly</a>
# <a href="/monthly/">Monthly</a>
# <a href="/quarterly/">Quarterly</a>
# <a href="/seasonal/">Seasonal</a>
# <a href="/yearly/">Yearly</a>
# <a href="/alltime/">All Time</a>
# <a href="/intl/">International</a>
# <a href="/studio/">Studios</a>
# <a href="/people/">People</a>
# <a href="/genres/">Genres</a>
# <a href="/franchises/">Franchises</a>
# <a href="/showdowns/">Showdowns</a>
# <a href="/counts/">Theater Counts</a>
# <a href="/about/adjuster.htm"><b>Adjuster:</b></a>
# <a href="/movies/?page=media&amp;id=biglebowski.htm"><img border="1" src="https://m.media-amazon.com/images/M/MV5BMTQ0NjUzMDMyOF5BMl5BanBnXkFtZTgwODA1OTU0MDE@._V1_UY222_CR0,0,150,222_AL.jpg" style="border-color: 000000"/></a>
# <a href="?page=releases&amp;id=biglebowski.htm"><b>Domestic Lifetime Gross: $18,034,458</b></a>
# <a href="/studio/chart/?studio=gramercy.htm">Gramercy</a>
# <a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=1998-03-06&amp;p=.htm">March 6, 1998</a>
# <a href="http://www.imdb.com/showtimes?ref_=mojo"><img src="/images/mojo_imdb_med.png" style="vertical-align:middle"/></a>
# <a href="http://www.imdb.com/showtimes?ref_=mojo">Get local showtimes at IMDb</a>
# <a href="/movies/?page=main&amp;id=biglebowski.htm">Summary</a>
# <a href="/movies/?page=weekend&amp;id=biglebowski.htm">Weekend</a>
# <a href="/movies/?page=weekly&amp;id=biglebowski.htm">Weekly</a>
# <a href="/movies/?page=releases&amp;id=biglebowski.htm">Releases</a>
# <a href="/movies/?page=similar&amp;id=biglebowski.htm">Similar Movies</a>
# <a href="/weekend/chart/?yr=1998&amp;wknd=10&amp;p=.htm">Opening Weekend:</a>
# <a href="/movies/?page=weekend&amp;id=biglebowski.htm"><b>&gt; View All 4 Weekends</b></a>
# <a href="/people/?view=Director&amp;p=.htm">Director:</a>
# <a href="/people/chart/?view=Director&amp;id=joelcoen.htm">Joel Coen</a>
# <a href="/people/?view=Writer&amp;p=.htm">Writers:</a>
# <a href="/people/chart/?view=Writer&amp;id=ethancoen.htm">Ethan Coen</a>
# <a href="/people/chart/?view=Writer&amp;id=joelcoen.htm">Joel Coen</a>
# <a href="/people/?view=Actor&amp;p=.htm">Actors:</a>
# <a href="/people/chart/?view=Actor&amp;id=jeffbridges.htm">Jeff Bridges</a>
# <a href="/people/chart/?view=Actor&amp;id=johngoodman.htm">John Goodman</a>
# <a href="/people/chart/?view=Actor&amp;id=juliannemoore.htm">Julianne Moore</a>
# <a href="/people/chart/?view=Actor&amp;id=philipseymourhoffman.htm">Philip Seymour Hoffman</a>
# <a href="/people/chart/?view=Actor&amp;id=samelliott.htm">Sam Elliott*</a>
# <a href="/people/?view=Producer&amp;p=.htm">Producers:</a>
# <a href="/people/chart/?view=Producer&amp;id=timbevan.htm">Tim Bevan</a>
# <a href="/people/chart/?view=Producer&amp;id=ethancoen.htm">Ethan Coen</a>
# <a href="/people/chart/?view=Producer&amp;id=ericfellner.htm">Eric Fellner</a>
# <a href="/people/?view=Cinematographer&amp;p=.htm"><font size="2">Cinematographer</font>:</a>
# <a href="/people/chart/?view=Cinematographer&amp;id=rogerdeakins.htm">Roger Deakins</a>
# <a href="/people/?view=Composer&amp;p=.htm">Composer:</a>
# <a href="/people/chart/?view=Composer&amp;id=carterburwell.htm">Carter Burwell</a>
# <a href="/genres/chart/?id=blackcomedy.htm">Comedy - Dark/Black</a>
# <a href="/genres/chart/?id=slackerstoner.htm">Slacker / Stoner</a>
# <a href="/alltime/domestic.htm">All Time Domestic</a>
# <a href="/yearly/chart/?yr=1998&amp;p=.htm">Yearly 1998</a>
# <a href="/yearly/chart/?view2=releasedate&amp;view=opening&amp;yr=1998&amp;p=.htm">Yearly Opening Weekends 1998</a>
# <a href="/yearly/chart/mpaarating.htm?rating=R&amp;yr=1998&amp;p=.htm">Yearly R Rated 1998</a>
# <a href="/yearly/chart/?view2=worldwide&amp;yr=1998&amp;p=.htm">Worldwide Yearly 1998</a>
# <a href="/alltime/openingweeks.htm">Opening Weeks</a>
# <a href="/alltime/weekends/">Opening Weekends</a>
# <a href="/alltime/weekends/smallestdrops.htm?page=SMALLDROPWID&amp;p=.htm">Smallest Drops, All Wide Releases</a>
# <a href="/alltime/domestic.htm?page=14&amp;asof=1998-04-10&amp;p=.htm">Highest All Time Rank (on April 10, 1998)</a>
# <a href="/yearly/chart/?view2=wide&amp;view=domestic&amp;yr=1998&amp;p=.htm">Yearly (Wide) 1998</a>
# <a href="/yearly/chart/?view2=opening&amp;yr=1998&amp;p=.htm">Yearly Opening Weekends (Wide) 1998</a>
# <a href="/alltime/openingweeks.htm?adjust_yr=2019&amp;p=.htm">Opening Weeks Adjusted</a>
# <a href="/alltime/weekends/?adjust_yr=2019&amp;p=.htm">Opening Weekends Adjusted</a>
# <a href="/news/?id=2680&amp;p=.htm">2/11/10 2010 Preview: True Grit</a>
# <a href="http://www.amazon.com/gp/product/B000A7DVR2?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000A7DVR2">The Big Lebowski (Collector's Edition)</a>
# <a href="http://www.amazon.com/gp/product/B000A7DVY0?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000A7DVY0">The Big Lebowski - Achiever's Edition</a>
# <a href="http://www.amazon.com/gp/product/B000ASATSU?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000ASATSU">The Coen Brothers Collection</a>
# <a href="http://www.amazon.com/gp/product/B000O179EK?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000O179EK">The Big Lebowski (HD-DVD)</a>
# <a href="http://www.amazon.com/gp/product/B000O179EK?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000O179EK">The Big Lebowski (HD-DVD)</a>
# <a href="http://www.amazon.com/gp/product/B001AEF6CW?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B001AEF6CW">The Big Lebowski (10th Anniv. Limited Edition)</a>
# <a href="http://www.amazon.com/gp/product/B001AEF6D6?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B001AEF6D6">The Big Lebowski (10th Anniv. Edition)</a>
# <a href="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=NoScript">Amazon.com Widgets</a>
# <a href="/news/?ref=ft">Movie News</a>
# <a href="/daily/chart/?ref=ft">Daily Chart</a>
# <a href="/weekend/chart/?ref=ft">Weekend Chart</a>
# <a href="/alltime/?ref=ft">All Time Charts</a>
# <a href="/intl/?ref=ft">International Charts</a>
# <a href="/people/?ref=ft">People</a>
# <a href="/genres/?ref=ft">Genres</a>
# <a href="/franchises/?ref=ft">Franchises</a>
# <a href="/showdowns/?ref=ft">Showdowns</a>
# <a href="/about/?ref=ft">About This Site</a>
# <a href="/about/advertise.htm?ref=ft">Advertising</a>
# <a href="/?ref=ft"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a>
# <a href="http://imdb.com/"><img alt="IMDb" height="16" src="/img/misc/IMDbSm.png" valign="middle" width="34"/></a>
# <a href="http://imdb.com/">IMDb.com</a>
# <a href="/about/termsofuse.htm">Terms of Use</a>
# <a href="/about/privacy.htm">Privacy Policy</a>

# %%
[link for link in soup.find_all('a') if 'joelcoen' in str(link)]
# Out:
# [<a href="/people/chart/?view=Director&amp;id=joelcoen.htm">Joel Coen</a>,
#  <a href="/people/chart/?view=Writer&amp;id=joelcoen.htm">Joel Coen</a>]

# %% [markdown]
# ## Beautiful Soup - More on Find

# %% [markdown]
# ### `href` Example

# %%
# retrieve the url from an anchor tag
soup.find('a')['href']
# Out:
# '/daily/chart/'

# %% [markdown]
# ### `id` and `class` examples

# %% [markdown]
# * An attribute like id or class can be matched
# * Example: 'mp_box_content' classes

# %%
soup.find_all(id='top_links')
# Out:
# [<div id="top_links">
#  <div style="float: left"><a href="/daily/chart/">Daily Box Office (Sun.)</a> | <a href="/weekend/chart/">Weekend Box Office (Oct. 11–13)</a> | <a href="/movies/?id=joker2019.htm">#1 Movie: 'Joker (2019)'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
#  <div style="float: right">Updated 10/13/2019 8:31 A.M. Pacific Time</div>
#  <div style="clear:both; height: 0px"></div>
#  </div>]

# %%
for element in soup.find_all(class_='mp_box_content'):
    print(element, '\n')
# Out:
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td width="40%"><b>Domestic:</b></td>
# <td align="right" width="35%"> <b>$18,034,458</b></td>
# <td align="right" width="25%">   <b>38.6%</b></td>
# </tr>
# <tr>
# <td width="40%">+ Foreign:</td>
# <td align="right" width="35%"> $28,690,764</td>
# <td align="right" width="25%">   61.4%</td>
# </tr>
# <tr>
# <td colspan="3" width="100%"><hr/></td>
# </tr>
# <tr>
# <td width="40%">= <b>Worldwide:</b></td>
# <td align="right" width="35%"> <b>$46,725,222</b></td>
# <td width="25%"> </td>
# </tr>
# </table>
# </div>
#
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="center"><a href="/weekend/chart/?yr=1998&amp;wknd=10&amp;p=.htm">Opening Weekend:</a></td><td> $5,533,844</td></tr>
# <tr>
# <td align="center" colspan="2"><font size="2">(#6 rank, 1,207 theaters, $4,585 average)</font></td></tr>
# <tr>
# <td align="right">% of Total Gross:</td><td> 31.7%</td></tr>
# <tr><td align="right" colspan="2"><font face="Helvetica, Arial, Sans-Serif" size="1"><a href="/movies/?page=weekend&amp;id=biglebowski.htm"><b>&gt; View All 4 Weekends</b></a></font></td></tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>Widest Release:</td>
# <td> 1,235 theaters</td>
# </tr>
# </table>
# </div>
#
# <div class="mp_box_content">
# <table>
# <tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Director&amp;p=.htm">Director:</a></font></td><td><font size="2"><a href="/people/chart/?view=Director&amp;id=joelcoen.htm">Joel Coen</a></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Writer&amp;p=.htm">Writers:</a></font></td><td><font size="2"><a href="/people/chart/?view=Writer&amp;id=ethancoen.htm">Ethan Coen</a><br/><a href="/people/chart/?view=Writer&amp;id=joelcoen.htm">Joel Coen</a></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Actor&amp;p=.htm">Actors:</a></font></td><td><font size="2"><a href="/people/chart/?view=Actor&amp;id=jeffbridges.htm">Jeff Bridges</a><br/><a href="/people/chart/?view=Actor&amp;id=johngoodman.htm">John Goodman</a><br/><a href="/people/chart/?view=Actor&amp;id=juliannemoore.htm">Julianne Moore</a><br/>Steve Buscemi<br/><a href="/people/chart/?view=Actor&amp;id=philipseymourhoffman.htm">Philip Seymour Hoffman</a><br/>Tara Reid<br/><a href="/people/chart/?view=Actor&amp;id=samelliott.htm">Sam Elliott*</a> <font size="2">(Narrator)</font></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Producer&amp;p=.htm">Producers:</a></font></td><td><font size="2"><a href="/people/chart/?view=Producer&amp;id=timbevan.htm">Tim Bevan</a> <font size="2">(executive producer)</font><br/><a href="/people/chart/?view=Producer&amp;id=ethancoen.htm">Ethan Coen</a><br/><a href="/people/chart/?view=Producer&amp;id=ericfellner.htm">Eric Fellner</a> <font size="2">(executive producer)</font></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Cinematographer&amp;p=.htm"><font size="2">Cinematographer</font>:</a></font></td><td><font size="2"><a href="/people/chart/?view=Cinematographer&amp;id=rogerdeakins.htm">Roger Deakins</a></font></td></tr><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Composer&amp;p=.htm">Composer:</a></font></td><td><font size="2"><a href="/people/chart/?view=Composer&amp;id=carterburwell.htm">Carter Burwell</a></font></td></tr><tr><td align="right" colspan="2"><i><small>* Denotes minor role</small></i></td></tr></table></div>
#
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr><th>Genre</th>
# <th>Rank</th></tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/genres/chart/?id=blackcomedy.htm">Comedy - Dark/Black</a></font></td>
# <td align="center"><font size="2">33</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/genres/chart/?id=slackerstoner.htm">Slacker / Stoner</a></font></td>
# <td align="center"><font size="2">34</font></td>
# </tr>
# </table></div>
#
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr><td bgcolor=""><b>Chart</b></td>
# <td align="center"><b>Rank</b></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/domestic.htm">All Time Domestic</a></font></td>
# <td align="center"><font size="2">3,686</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/?yr=1998&amp;p=.htm">Yearly 1998</a></font></td>
# <td align="center"><font size="2">96</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=releasedate&amp;view=opening&amp;yr=1998&amp;p=.htm">Yearly Opening Weekends 1998</a></font></td>
# <td align="center"><font size="2">88</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/mpaarating.htm?rating=R&amp;yr=1998&amp;p=.htm">Yearly R Rated 1998</a></font></td>
# <td align="center"><font size="2">41</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=worldwide&amp;yr=1998&amp;p=.htm">Worldwide Yearly 1998</a></font></td>
# <td align="center"><font size="2">54</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/openingweeks.htm">Opening Weeks</a></font></td>
# <td align="center"><font size="2">3,232</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/">Opening Weekends</a></font></td>
# <td align="center"><font size="2">3,131</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/weekends/smallestdrops.htm?page=SMALLDROPWID&amp;p=.htm">Smallest Drops, All Wide Releases</a></font></td>
# <td align="center"><font size="2">1,690</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2">BOM Users' Grades (1998 Releases)</font></td>
# <td align="center"><font size="2">15</font></td>
# </tr>
# <tr><td><b>Charts (Premier Pass Users Only)</b></td><td align="center"><b>Rank</b></td></tr><tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/domestic.htm?page=14&amp;asof=1998-04-10&amp;p=.htm">Highest All Time Rank (on April 10, 1998)</a></font></td>
# <td align="center"><font size="2">1364</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/?view2=wide&amp;view=domestic&amp;yr=1998&amp;p=.htm">Yearly (Wide) 1998</a></font></td>
# <td align="center"><font size="2">90</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=opening&amp;yr=1998&amp;p=.htm">Yearly Opening Weekends (Wide) 1998</a></font></td>
# <td align="center"><font size="2">91</font></td>
# </tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/openingweeks.htm?adjust_yr=2019&amp;p=.htm">Opening Weeks Adjusted</a></font></td>
# <td align="center"><font size="2">2,985</font></td>
# </tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/?adjust_yr=2019&amp;p=.htm">Opening Weekends Adjusted</a></font></td>
# <td align="center"><font size="2">2,904</font></td>
# </tr>
# </table></div>
#
# <div class="mp_box_content"><table border="0" cellpadding="5" cellspacing="0" width="100%"><tr bgcolor="#ffff99"><td><font size="2"><a href="/news/?id=2680&amp;p=.htm">2/11/10 2010 Preview: True Grit</a></font></td></tr></table></div>
#
# <div class="mp_box_content"><ul>
# <li><a href="http://www.amazon.com/gp/product/B000A7DVR2?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000A7DVR2">The Big Lebowski (Collector's Edition)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000A7DVR2" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000A7DVY0?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000A7DVY0">The Big Lebowski - Achiever's Edition</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000A7DVY0" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000ASATSU?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000ASATSU">The Coen Brothers Collection</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000ASATSU" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000O179EK?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000O179EK">The Big Lebowski (HD-DVD)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000O179EK" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B000O179EK?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000O179EK">The Big Lebowski (HD-DVD)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B000O179EK" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B001AEF6CW?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B001AEF6CW">The Big Lebowski (10th Anniv. Limited Edition)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B001AEF6CW" style="border:none !important; margin:0px !important;" width="1"/></li>
# <li><a href="http://www.amazon.com/gp/product/B001AEF6D6?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B001AEF6D6">The Big Lebowski (10th Anniv. Edition)</a><img alt="" border="0" height="1" src="//www.assoc-amazon.com/e/ir?t=boxofficemojo-20&amp;l=as2&amp;o=1&amp;a=B001AEF6D6" style="border:none !important; margin:0px !important;" width="1"/></li>
# </ul></div>

# %% [markdown]
# ## Beautiful Soup - Chaining Finds

# %% [markdown]
# All the fields in mp_box_content can be found by "chaining" a few `find_all` functions.

# %%
# 'td' is for a cell in an HTML table
chain = [x.find_all('td') for x in soup.find_all(class_='mp_box_content')]

# %%
# for the first mp_box_content find all td's
chain[0]
# Out:
# [<td width="40%"><b>Domestic:</b></td>,
#  <td align="right" width="35%"> <b>$18,034,458</b></td>,
#  <td align="right" width="25%">   <b>38.6%</b></td>,
#  <td width="40%">+ Foreign:</td>,
#  <td align="right" width="35%"> $28,690,764</td>,
#  <td align="right" width="25%">   61.4%</td>,
#  <td colspan="3" width="100%"><hr/></td>,
#  <td width="40%">= <b>Worldwide:</b></td>,
#  <td align="right" width="35%"> <b>$46,725,222</b></td>,
#  <td width="25%"> </td>]

# %% [markdown]
# To extract just the value of interest:

# %%
# Find the domestic gross. The '\xa0' represents a space in unicode
soup.find(class_='mp_box_content').find_all('td')[1].text
# Out:
# '\xa0$18,034,458'

# %%
# There are 2 td's the second one has the $17,451,873 and we remove the space character
soup.find(class_='mp_box_content').find_all('td')[1].text[1:]
# Out:
# '$18,034,458'

# %% [markdown]
# ## Let's Practice Web Scraping!

# %% [markdown]
# ### Items to scrape for each movie:

# %% [markdown]
# * Movie Title
# * Domestic Total Gross
# * Runtime
# * MPAA Rating
# * Release Date

# %% [markdown]
# ### Movie Title

# %%
soup.find('title')
# Out:
# <title>The Big Lebowski (1998) - Box Office Mojo</title>

# %%
soup.find('title').text
# Out:
# 'The Big Lebowski (1998) - Box Office Mojo'

# %%
title_string = soup.find('title').text
title_string
# Out:
# 'The Big Lebowski (1998) - Box Office Mojo'

# %%
title_string.split('(')
# Out:
# ['The Big Lebowski ', '1998) - Box Office Mojo']

# %%
# .strip() removes the white spaces at the beginning and end of the string
title = title_string.split('(')[0].strip() 
title
# Out:
# 'The Big Lebowski'

# %% [markdown]
# ### Domestic Total Gross

# %% [markdown]
# Let's try to find the exact text.

# %%
print(soup.find(text="Domestic Total Gross"))
# Out:
# None

# %% [markdown]
# `Text` does an exact match search, so we have to be careful.

# %%
print(soup.find(text="Domestic Total Gross: "))
# Out:
# Domestic Total Gross:

# %% [markdown]
# What if we don't want to be careful? [Regular expressions](https://xkcd.com/208/) to the rescue!
#
# We are going to talk a lot more about regular expressions in the next week or two, but there's a really powerful way to search for patterns in text. Today, we're going to use a very simple case, basically doing a "contains" instead of an "exact match".

# %%
import re
domestic_total_regex = re.compile('Domestic Total') #results in a pattern object 
domestic_total_regex
# Out:
# re.compile(r'Domestic Total', re.UNICODE)

# %%
dtg_string = soup.find(text=domestic_total_regex)
dtg_string
# Out:
# 'Domestic Total Gross: '

# %%
dtg_string.findNextSibling()
# Out:
# <b>$17,451,873</b>

# %% [markdown]
# We found the domestic total gross! Now let's strip it down and convert it to an integer.

# %%
dtg = dtg_string.findNextSibling().text
print(dtg, type(dtg))

dtg = dtg.replace('$','').replace(',','')
print(dtg, type(dtg))

domestic_total_gross = int(dtg)
print(domestic_total_gross, type(domestic_total_gross))
# Out:
# $17,451,873 <class 'str'>
# 17451873 <class 'str'>
# 17451873 <class 'int'>

# %% [markdown]
# ### Runtime, MPAA Rating & Release Date

# %% [markdown]
# #### Step 1: Create Function to Identify Values

# %% [markdown]
# Let's make a function to scrape multiple things, assuming the value will always follow the field name.

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_sibling = obj.findNextSibling()
    
    if next_sibling:
        return next_sibling.text 
    else:
        return None

# %%
# domestic total gross
dtg = get_movie_value(soup,'Domestic Total')
print(dtg)
# Out:
# $17,451,873

# %%
# runtime
runtime = get_movie_value(soup,'Runtime')
print(runtime)
# Out:
# 1 hrs. 57 min.

# %%
# rating
rating = get_movie_value(soup,'MPAA Rating')
print(rating)
# Out:
# R

# %%
release_date = get_movie_value(soup,'Release Date')
print(release_date)
# Out:
# March 6, 1998

# %% [markdown]
# #### Step 2: Convert Values to Appropriate Data Types

# %%
import dateutil.parser

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# #### Step 3: Apply the Conversions

# %%
# Let's get these again and format them all in one swoop

raw_domestic_total_gross = get_movie_value(soup,'Domestic Total')
domestic_total_gross = money_to_int(raw_domestic_total_gross)

raw_runtime = get_movie_value(soup,'Runtime')
runtime = runtime_to_minutes(raw_runtime)

raw_release_date = get_movie_value(soup,'Release Date')
release_date = to_date(raw_release_date)

print(domestic_total_gross, runtime, release_date)
print(type(domestic_total_gross), type(runtime), type(release_date))
# Out:
# 17451873 117 1998-03-06 00:00:00
# <class 'int'> <class 'int'> <class 'datetime.datetime'>

# %% [markdown]
# #### Step 4: Print It All Out

# %%
from pprint import pprint # pretty print

headers = ['movie title', 'domestic total gross',
           'runtime (mins)', 'rating', 'release date']

movie_data = []
movie_dict = dict(zip(headers, [title,
                                domestic_total_gross,
                                runtime,
                                rating, 
                                release_date]))

movie_data.append(movie_dict)
pprint(movie_data)
# Out:
# [{'domestic total gross': 17451873,
#   'movie title': 'The Big Lebowski',
#   'rating': 'R',
#   'release date': datetime.datetime(1998, 3, 6, 0, 0),
#   'runtime (mins)': 117}]

# %% [markdown]
# ## Table Scraping Example

# %% [markdown]
# ### Step 1: Soupify the Website

# %% [markdown]
# Let's take a look at the foreign language page of Box Office Mojo. Let's say we wanted to pull all of the data from the main table on the page.

# %%
url = 'http://www.boxofficemojo.com/genres/chart/?id=foreign.htm'

response = requests.get(url)
page = response.text

soup = BeautifulSoup(page,"lxml")

# %% [markdown]
# ### Step 2: Find the Tables

# %%
tables = soup.find_all("table")
tables
# Out:
# [<table class="table-condensed table-striped table-bordered">
#  <thead></thead>
#  <tbody>
#  <tr>
#  <th scope="row">Query</th>
#  <td><code>https://data.gov.sg/api/action/datastore_search</code></td>
#  </tr>
#  </tbody>
#  </table>, <table class="table table-condensed">
#  <col class="field-index"/>
#  <col class="field-name"/>
#  <col class="field-title"/>
#  <col class="field-type"/>
#  <col class="field-units"/>
#  <col class="field-desc"/>
#  <thead>
#  <tr>
#  <th class="field-index">No.</th>
#  <th class="field-name">Name</th>
#  <th class="field-title">Title</th>
#  <th class="field-type">Type</th>
#  <th class="field-units">Unit of Measure</th>
#  <th class="field-desc">Description</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="field-index" width="10%">1</td>
#  <td>year</td>
#  <td>Year</td>
#  <td class="field-type">
#              Datetime (Year)
#
#                <br/>
#                "YYYY"
#
#
#            </td>
#  <td>-</td>
#  <td>
#
#              -
#            </td>
#  </tr>
#  <tr>
#  <td class="field-index" width="10%">2</td>
#  <td>eweek</td>
#  <td>Eweek</td>
#  <td class="field-type">
#              Numeric (General)
#
#
#            </td>
#  <td>Week</td>
#  <td>
#
#              -
#            </td>
#  </tr>
#  <tr>
#  <td class="field-index" width="10%">3</td>
#  <td>type_dengue</td>
#  <td>Type dengue</td>
#  <td class="field-type">
#              Text (General)
#
#
#            </td>
#  <td>-</td>
#  <td>
#
#              -
#            </td>
#  </tr>
#  <tr>
#  <td class="field-index" width="10%">4</td>
#  <td>number</td>
#  <td>Number</td>
#  <td class="field-type">
#              Text (General)
#
#
#            </td>
#  <td>-</td>
#  <td>
#
#              -
#            </td>
#  </tr>
#  </tbody>
#  </table>, <table class="table table-condensed">
#  <thead>
#  <tr>
#  <th class="field-index text-center">No.</th>
#  <th>Column</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="field-index">1</td>
#  <td>
#  <div><strong>Name:</strong> year </div>
#  <div><strong>Title:</strong> Year</div>
#  <div>
#  <strong>Type:</strong>
#  <div class="field-type">Datetime (Year)
#
#                <div>"YYYY"</div>
#  </div>
#  <div>
#  <strong>Unit of Measure:</strong>
#                -
#              </div>
#  <div>
#  <strong>Description:</strong>
#
#                -
#              </div>
#  </div></td>
#  </tr>
#  <tr>
#  <td class="field-index">2</td>
#  <td>
#  <div><strong>Name:</strong> eweek </div>
#  <div><strong>Title:</strong> Eweek</div>
#  <div>
#  <strong>Type:</strong>
#  <div class="field-type">Numeric (General)
#
#
#              </div>
#  <div>
#  <strong>Unit of Measure:</strong>
#                Week
#              </div>
#  <div>
#  <strong>Description:</strong>
#
#                -
#              </div>
#  </div></td>
#  </tr>
#  <tr>
#  <td class="field-index">3</td>
#  <td>
#  <div><strong>Name:</strong> type_dengue </div>
#  <div><strong>Title:</strong> Type dengue</div>
#  <div>
#  <strong>Type:</strong>
#  <div class="field-type">Text (General)
#
#
#              </div>
#  <div>
#  <strong>Unit of Measure:</strong>
#                -
#              </div>
#  <div>
#  <strong>Description:</strong>
#
#                -
#              </div>
#  </div></td>
#  </tr>
#  <tr>
#  <td class="field-index">4</td>
#  <td>
#  <div><strong>Name:</strong> number </div>
#  <div><strong>Title:</strong> Number</div>
#  <div>
#  <strong>Type:</strong>
#  <div class="field-type">Text (General)
#
#
#              </div>
#  <div>
#  <strong>Unit of Measure:</strong>
#                -
#              </div>
#  <div>
#  <strong>Description:</strong>
#
#                -
#              </div>
#  </div></td>
#  </tr>
#  </tbody>
#  </table>, <table class="table table-condensed" data-module="table-toggle-more">
#  <tbody>
#  <tr>
#  <th scope="row">Last updated</th>
#  <td>September 30, 2019</td>
#  </tr>
#  <tr>
#  <th scope="row">Created</th>
#  <td>September 30, 2019</td>
#  </tr>
#  <tr>
#  <th scope="row">Format</th>
#  <td>CSV</td>
#  </tr>
#  <tr>
#  <th scope="row">Coverage</th>
#  <td>
#
#                        January 1, 2014 to December 31, 2018
#
#                    </td>
#  </tr>
#  <tr>
#  <th scope="row">Licence</th>
#  <td class="dataset-details"><a href="/open-data-licence" rel="dc:rights">Singapore Open Data Licence</a></td>
#  </tr>
#  </tbody>
#  </table>, <table class="table">
#  <tbody>
#  <tr>
#  <th scope="row">Managed By</th>
#  <td><a href="/dataset?organization=ministry-of-health">Ministry of Health</a></td>
#  </tr>
#  <tr>
#  <th scope="row">Last Updated</th>
#  <td>September 30, 2019, 10:33 (SGT)</td>
#  </tr>
#  <tr>
#  <th scope="row">Created</th>
#  <td>September 30, 2019, 09:59 (SGT)</td>
#  </tr>
#  <tr>
#  <th scope="row">Coverage</th>
#  <td>January 1, 2014 to December 31, 2018</td>
#  </tr>
#  <tr>
#  <th scope="row">Frequency</th>
#  <td>Weekly</td>
#  </tr>
#  <tr>
#  <th scope="row">Source(s)</th>
#  <td>Ministry of Health</td>
#  </tr>
#  <tr>
#  <th scope="row">Licence</th>
#  <td><a href="/open-data-licence">Singapore Open Data Licence</a></td>
#  </tr>
#  </tbody>
#  </table>]

# %% [markdown]
# ### Step 3: Pull Just the Rows

# %%
rows = [row for row in tables[3].find_all('tr')] # tr tag is for rows

# %%
# let's take a look at one row
rows[0]
# Out:
# <tr>
# <th scope="row">Last updated</th>
# <td>September 30, 2019</td>
# </tr>

# %%
# let's take a look at one value in the row
rows[0].find_all('td')[1].find('a')['href']
# Out:
# '/genres/chart/?id=foreign.htm&sort=title&order=ASC&p=.htm'

# %% [markdown]
# ### Step 4: Pull All Values

# %%
rows[1].find_all('td')[1].find('a')['href']
# Out:
# '/movies/?id=crouchingtigerhiddendragon.htm'

# %%
rows = rows[1:21] # let's just look at the first 20 rows for now
movies = {}

for row in rows:
    items = row.find_all('td')
    title = items[1].find('a')['href']
    movies[title] = [i.text for i in items[1:]]
    
list(movies.items())[0]
# Out:
# ('/movies/?id=crouchingtigerhiddendragon.htm',
#  ['Crouching Tiger, Hidden Dragon(Taiwan)',
#   'SPC',
#   '$128,078,872',
#   '2,027',
#   '$663,205',
#   '16',
#   '12/8/00'])

# %% [markdown]
# ### Step 5: Pandas Alternative

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-9db58c4aee3b> in <module>
#      10 r = requests.get(url, headers=header)
#      11
# ---> 12 dfs = pd.read_html(r)
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# //anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#      44     if traceback == Ellipsis:
#      45         _, _, traceback = sys.exc_info()
# ---> 46     raise exc.with_traceback(traceback)
#      47
#      48
#
# TypeError: Cannot read object of type 'Response'

# %%
# you can also use pandas to read tables
import pandas as pd

url = 'https://eshop-prices.com/prices?currency=SGD'

# %%
tables = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-62-3bac92017238> in <module>
# ----> 1 tables = pd.read_html(url)
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# //anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#      44     if traceback == Ellipsis:
#      45         _, _, traceback = sys.exc_info()
# ---> 46     raise exc.with_traceback(traceback)
#      47
#      48
#
# HTTPError: HTTP Error 403: Forbidden

# %%
tables[2]
# how can you fix the header?
# Out:
#                                                  0       1             2
# 0                            Title (click to view)  Studio  Release Date
# 1                        Tampopo (2016 re-release)    Jan.      10/21/16
# 2                                  Cyrano, My Love   RAtt.      10/18/19
# 3                              By The Grace of God    MBox      10/18/19
# 4                                      Housefull 4     FIP      10/25/19
# 5                       Portrait of a Lady on Fire    Neon       12/6/19
# 6                                      The Traitor     SPC       1/31/20
# 7   Las Pildoras de Mi Novio (My Boyfriend's Meds)     PNT       2/21/20
# 8                                 Johanna(Hungary)    Tar.           TBD
# 9                                             Abel     LGF           TBD
# 10          When a Wolf Falls in Love with a Sheep     NaN           TBD
# 11                                       Jolly LLB     FIP           TBD
# 12                           Happy New Year (2014)     NaN           TBD
# 13                                 Suite Francaise   Wein.           TBD
# 14                               Theri (The Spark)     NaN           TBD
# 15                                       24 (2016)    Eros           TBD
# 16                     The Girl with All the Gifts   Saban           TBD
# 17                  Pitbull. Niebezpieczne kobiety     NaN           TBD
# 18                                The Jungle Bunch     NaN           TBD
# 19                                          Botoks     NaN           TBD
# 20                                          Mersal     NaN           TBD
# 21                                   Listy do M. 3     NaN           TBD
# 22                                   Kobiety Mafii     NaN           TBD
# 23                                           Raazi     NaN           TBD
# 24                                           Kaala     NaN           TBD
# 25                                            Kler     NaN           TBD
# 26                                Planeta Singli 2     NaN           TBD
# 27                                 Kobiety mafii 2     NaN           TBD
# 28                                         Muklawa     NaN           TBD
# 29                                     Better Days   WGUSA           TBD

# %%
tables[2][0:5]
# Out:
#                            0       1             2
# 0      Title (click to view)  Studio  Release Date
# 1  Tampopo (2016 re-release)    Jan.      10/21/16
# 2            Cyrano, My Love   RAtt.      10/18/19
# 3        By The Grace of God    MBox      10/18/19
# 4                Housefull 4     FIP      10/25/19

# %% [markdown]
# Conclusion: Beautiful Soup is powerful but it has many limitations. If a page needs interactions (like entering password) or if a page is not static, but dynamically generated, we can't use Soup. We will explore other tools for that.

# %% [markdown]
# One such tool for tomorrow: *Selenium*
